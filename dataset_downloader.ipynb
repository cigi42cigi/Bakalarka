# %%
import csv, os, subprocess
from urllib.request import urlretrieve

# Nastavení
CSV_FILE = "unbalanced_train_segments.csv"
CSV_URL = "https://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/unbalanced_train_segments.csv"
GUNSHOT_MID = "/m/03qtq"
DOWNLOAD_DIR = "gunshots_audioset"

os.makedirs(DOWNLOAD_DIR, exist_ok=True)

# Stáhnout CSV pokud není
if not os.path.exists(CSV_FILE):
    print("📥 Stahuji anotace...")
    urlretrieve(CSV_URL, CSV_FILE)

# Načíst a vyfiltrovat gunshot segmenty
gunshots = []
with open(CSV_FILE, newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        if row[0].startswith("#"):  # přeskočíme hlavičku
            continue
        labels = row[3].strip().strip('"').split(',')
        if GUNSHOT_MID in labels:
            gunshots.append(row)

print(f"🔫 Nalezeno {len(gunshots)} gunshot segmentů v unbalanced setu")

# Stáhnout a vyříznout segmenty
for i, row in enumerate(gunshots[:300]):  # změň na len(gunshots) pro ALL
    ytid = row[0].strip('"')
    start = float(row[1])
    end = float(row[2])
    outname = f"{ytid}_{int(start*1000)}_{int(end*1000)}.wav"
    outpath = os.path.join(DOWNLOAD_DIR, outname)
    if os.path.exists(outpath):
        continue

    print(f"[{i+1}/{len(gunshots)}] ⬇️ {outname}")
    try:
        subprocess.run([
            "yt-dlp",
            "-f", "bestaudio[ext=m4a]",
            "--quiet",
            "--no-warnings",
            f"https://www.youtube.com/watch?v={ytid}",
            "-o", "temp.m4a"
        ], check=True)

        subprocess.run([
            "ffmpeg",
            "-loglevel", "quiet",
            "-y",
            "-ss", str(start),
            "-to", str(end),
            "-i", "temp.m4a",
            "-ar", "16000",
            "-ac", "1",
            outpath
        ], check=True)

    except subprocess.CalledProcessError as e:
        print(f"⚠️ Chyba u {ytid}: {e}")
        continue

if os.path.exists("temp.m4a"):
    os.remove("temp.m4a")

print("✅ Vše hotovo!")
# Out:
# 📥 Stahuji anotace...
# 🔫 Nalezeno 398 gunshot segmentů v unbalanced setu
# [1/398] ⬇️ -0-9MjhjYXo_30000_40000.wav
# [2/398] ⬇️ -0DGa_6exhc_30000_40000.wav
# [3/398] ⬇️ -6uW8qkvA5A_30000_40000.wav
# [4/398] ⬇️ -D9gxkL5jnQ_23000_33000.wav
# [5/398] ⬇️ -LBdsxhIEvo_0_10000.wav
# [6/398] ⬇️ -ZFflYSjN20_50000_60000.wav
# ERROR: [youtube] -ZFflYSjN20: Video unavailable
# ⚠️ Chyba u -ZFflYSjN20: Command '['yt-dlp', '-f', 'bestaudio[ext=m4a]', '--quiet', '--no-warnings', 'https://www.youtube.com/watch?v=-ZFflYSjN20', '-o', 'temp.m4a']' returned non-zero exit status 1.
# [7/398] ⬇️ -gBpGXiZ6E0_220000_230000.wav
# [8/398] ⬇️ -gbW7u8t9y4_19000_29000.wav
# [9/398] ⬇️ -xHXCw5_Va4_10000_20000.wav
# [10/398] ⬇️ 00XluwV4_Do_30000_40000.wav
# [11/398] ⬇️ 0Owq5Nm49EY_30000_40000.wav
# [12/398] ⬇️ 0aKZHa0wk_Y_30000_40000.wav
# ERROR: [youtube] 0aKZHa0wk_Y: Requested format is not available. Use --list-formats for a list of available formats
# ⚠️ Chyba u 0aKZHa0wk_Y: Command '['yt-dlp', '-f', 'bestaudio[ext=m4a]', '--quiet', '--no-warnings', 'https://www.youtube.com/watch?v=0aKZHa0wk_Y', '-o', 'temp.m4a']' returned non-zero exit status 1.
# [13/398] ⬇️ 0bnhxHX_IWI_12000_22000.wav
# [14/398] ⬇️ 0iuyj4W7v0k_30000_40000.wav
# [15/398] ⬇️ 0nxQwgeGETM_9000_19000.wav
# [16/398] ⬇️ 0z3f7FIVc1E_30000_40000.wav
# [17/398] ⬇️ 1IX6UMUDho0_30000_40000.wav
# ERROR: [youtube] 1IX6UMUDho0: Private video. Sign in if you've been granted access to this video. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ⚠️ Chyba u 1IX6UMUDho0: Command '['yt-dlp', '-f', 'bestaudio[ext=m4a]', '--quiet', '--no-warnings', 'https://www.youtube.com/watch?v=1IX6UMUDho0', '-o', 'temp.m4a']' returned non-zero exit status 1.
# [18/398] ⬇️ 1J05b-kiIEM_270000_280000.wav
# [19/398] ⬇️ 1XhssJxMwc8_30000_40000.wav
# [20/398] ⬇️ 1aHUowNW-R8_40000_50000.wav
# ERROR: Interrupted by user
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 42
#      40 print(f"[{i+1}/{len(gunshots)}] ⬇️ {outname}")
#      41 try:
# ---> 42     subprocess.run([
#      43         "yt-dlp",
#      44         "-f", "bestaudio[ext=m4a]",
#      45         "--quiet",
#      46         "--no-warnings",
#      47         f"https://www.youtube.com/watch?v={ytid}",
#      48         "-o", "temp.m4a"
#      49     ], check=True)
#      51     subprocess.run([
#      52         "ffmpeg",
#      53         "-loglevel", "quiet",
#    (...)
#      60         outpath
#      61     ], check=True)
#      63 except subprocess.CalledProcessError as e:
#
# File /usr/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File /usr/lib/python3.10/subprocess.py:1146, in Popen.communicate(self, input, timeout)
#    1144         stderr = self.stderr.read()
#    1145         self.stderr.close()
# -> 1146     self.wait()
#    1147 else:
#    1148     if timeout is not None:
#
# File /usr/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File /usr/lib/python3.10/subprocess.py:1959, in Popen._wait(self, timeout)
#    1957 if self.returncode is not None:
#    1958     break  # Another thread waited.
# -> 1959 (pid, sts) = self._try_wait(0)
#    1960 # Check the pid and loop as waitpid has been known to
#    1961 # return 0 even without WNOHANG in odd situations.
#    1962 # http://bugs.python.org/issue14396.
#    1963 if pid == self.pid:
#
# File /usr/lib/python3.10/subprocess.py:1917, in Popen._try_wait(self, wait_flags)
#    1915 """All callers to this function MUST hold self._waitpid_lock."""
#    1916 try:
# -> 1917     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1918 except ChildProcessError:
#    1919     # This happens if SIGCLD is set to be ignored or waiting
#    1920     # for child processes has otherwise been disabled for our
#    1921     # process.  This child is dead, we can't get the status.
#    1922     pid = self.pid
#
# KeyboardInterrupt:

# %% [markdown]
# FreeSound

# %%
import freesound
import os

# 🔑 API klíč
API_KEY = "VV7pMu2KzRHPQkBZAFeSg96sH4hPdHi6OMryNnCc"

client = freesound.FreesoundClient()
client.set_token(API_KEY, "token")

# 📁 Cílová složka
output_dir = "freesound_gunshots"
os.makedirs(output_dir, exist_ok=True)

# 🔍 Vyhledání výsledků (BEZ filtru, pro jistotu)
pager = client.text_search(query="gunshot", page_size=15)

print("🔍 Výpis výsledků:\n")
for i, sound in enumerate(pager):
    print(f"[{i+1}] {sound.name} (ID: {sound.id}) | Licence: {sound.license}")
    try:
        # 🟢 Vytažení jména a cesty k souboru
        filename = f"{sound.id}_{sound.name.replace(' ', '_').replace('/', '_')}.mp3"
        filepath = os.path.join(output_dir, filename)

        # ⬇️ Stažení náhledu (preview MP3)
        preview_url = sound.previews.preview_lq_mp3
        import urllib.request
        urllib.request.urlretrieve(preview_url, filepath)
        print(f"   ✅ Uloženo jako {filename}")
    except Exception as e:
        print(f"   ❌ Chyba: {e}")

print("\n✅ Hotovo!")
# Out:
# 🔍 Výpis výsledků:
#
# [1] archi_gunshot_scifi_05.flac (ID: 507488) | Licence: http://creativecommons.org/publicdomain/zero/1.0/
#    ✅ Uloženo jako 507488_archi_gunshot_scifi_05.flac.mp3
# [2] archi_gunshot_scifi_07.flac (ID: 507486) | Licence: http://creativecommons.org/publicdomain/zero/1.0/
#    ✅ Uloženo jako 507486_archi_gunshot_scifi_07.flac.mp3
# [3] archi_gunshot_scifi_06.flac (ID: 507487) | Licence: http://creativecommons.org/publicdomain/zero/1.0/
#    ✅ Uloženo jako 507487_archi_gunshot_scifi_06.flac.mp3
# [4] archi_gunshot_scifi_08.flac (ID: 507485) | Licence: http://creativecommons.org/publicdomain/zero/1.0/
#    ✅ Uloženo jako 507485_archi_gunshot_scifi_08.flac.mp3
# [5] archi_gunshot_scifi_01.flac (ID: 507484) | Licence: http://creativecommons.org/publicdomain/zero/1.0/
#    ✅ Uloženo jako 507484_archi_gunshot_scifi_01.flac.mp3
# [6] archi_gunshot_scifi_03.flac (ID: 507482) | Licence: http://creativecommons.org/publicdomain/zero/1.0/
#    ✅ Uloženo jako 507482_archi_gunshot_scifi_03.flac.mp3
# [7] throwing stuff in dumpster sounds like gunshots (ID: 562868) | Licence: http://creativecommons.org/publicdomain/zero/1.0/
#    ✅ Uloženo jako 562868_throwing_stuff_in_dumpster_sounds_like_gunshots.mp3
# [8] Assault rifle suppressor gunshot. (ID: 539141) | Licence: http://creativecommons.org/publicdomain/zero/1.0/
#    ✅ Uloženo jako 539141_Assault_rifle_suppressor_gunshot..mp3
# [9] archi_gunshot_scifi_02.flac (ID: 507483) | Licence: http://creativecommons.org/publicdomain/zero/1.0/
#    ✅ Uloženo jako 507483_archi_gunshot_scifi_02.flac.mp3
# [10] Layered Gunshot 8.wav (ID: 128302) | Licence: http://creativecommons.org/publicdomain/zero/1.0/
#    ✅ Uloženo jako 128302_Layered_Gunshot_8.wav.mp3
# [11] Layered Gunshot 5.wav (ID: 128299) | Licence: http://creativecommons.org/publicdomain/zero/1.0/
#    ✅ Uloženo jako 128299_Layered_Gunshot_5.wav.mp3
# [12] Rifle gunshot, just one shot (ID: 709873) | Licence: http://creativecommons.org/publicdomain/zero/1.0/
#    ✅ Uloženo jako 709873_Rifle_gunshot,_just_one_shot.mp3
# [13] gunshot.m4a (ID: 516684) | Licence: http://creativecommons.org/publicdomain/zero/1.0/
#    ✅ Uloženo jako 516684_gunshot.m4a.mp3
# [14] gunshot__high_5.wav (ID: 402012) | Licence: https://creativecommons.org/licenses/by/4.0/
#    ✅ Uloženo jako 402012_gunshot__high_5.wav.mp3
# [15] gunshot__high_3.wav (ID: 402008) | Licence: https://creativecommons.org/licenses/by/4.0/
#    ✅ Uloženo jako 402008_gunshot__high_3.wav.mp3
#
# ✅ Hotovo!

# %%
import freesound
import os
import urllib.request

API_KEY = "VV7pMu2KzRHPQkBZAFeSg96sH4hPdHi6OMryNnCc"
client = freesound.FreesoundClient()
client.set_token(API_KEY, "token")

output_dir = "freesound_gunshots"
os.makedirs(output_dir, exist_ok=True)

queries = ["gunshot", "rifle", "pistol", "machine gun", "shotgun"]
downloaded_ids = set()

# Omezovač
MAX_SOUNDS_PER_QUERY = 3000
query_downloaded = 0

for query in queries:
    print(f"\n🔎 Hledám: {query}")
    pager = client.text_search(
        query=query,
        fields="id,name,previews",
        page_size=50,
        sort="score"
    )

    while pager:
        
        for sound in pager:
            if query_downloaded >= MAX_SOUNDS_PER_QUERY:
                print(f"⚠️ Limit {MAX_SOUNDS_PER_QUERY} zvuků pro '{query}' dosažen.")
                break

            if sound.id in downloaded_ids:
                continue
            safe_name = f"{sound.id}_{sound.name.replace(' ', '_').replace('/', '_')}.mp3"
            path = os.path.join(output_dir, safe_name)
            if os.path.exists(path):
                downloaded_ids.add(sound.id)
                query_downloaded += 1
                continue
            try:
                preview_url = sound.previews.preview_lq_mp3
                if not preview_url or preview_url == "None":
                    print(f"❌ Chyba: {sound.name} nemá dostupný MP3 náhled.")
                    continue
                print(f"⬇️ {safe_name}")
                urllib.request.urlretrieve(preview_url, path)
                downloaded_ids.add(sound.id)
            except Exception as e:
                print(f"❌ Chyba u {sound.name}: {e}")

        
        if pager.next is None:
            break
        pager = pager.next_page()


print(f"\n✅ Hotovo! Staženo {len(downloaded_ids)} unikátních zvuků.")
# Out:
# 🔎 Hledám: gunshot
# ⬇️ 507488_archi_gunshot_scifi_05.flac.mp3
# ⬇️ 507486_archi_gunshot_scifi_07.flac.mp3
# ⬇️ 507487_archi_gunshot_scifi_06.flac.mp3
# ⬇️ 507485_archi_gunshot_scifi_08.flac.mp3
# ⬇️ 507484_archi_gunshot_scifi_01.flac.mp3
# ⬇️ 507482_archi_gunshot_scifi_03.flac.mp3
# ⬇️ 562868_throwing_stuff_in_dumpster_sounds_like_gunshots.mp3
# ⬇️ 539141_Assault_rifle_suppressor_gunshot..mp3
# ⬇️ 507483_archi_gunshot_scifi_02.flac.mp3
# ⬇️ 128302_Layered_Gunshot_8.wav.mp3
# ⬇️ 128299_Layered_Gunshot_5.wav.mp3
# ⬇️ 709873_Rifle_gunshot,_just_one_shot.mp3
# ⬇️ 516684_gunshot.m4a.mp3
# ⬇️ 402012_gunshot__high_5.wav.mp3
# ⬇️ 402008_gunshot__high_3.wav.mp3
# ⬇️ 344524_Gunshot02.wav.mp3
# ⬇️ 128301_Layered_Gunshot_9.wav.mp3
# ⬇️ 507481_archi_gunshot_scifi_04.flac.mp3
# ⬇️ 710084_Rifle_gunshot,_one_shot.mp3
# ⬇️ 687398_9mm__Gunshot.mp3.mp3
# ⬇️ 660404_Laser_gunshot.mp3
# ⬇️ 638892_Single_Gunshot.mp3
# ⬇️ 501108_8-bit_gunshot.wav.mp3
# ⬇️ 501101_8-bit_gunshot_2.wav.mp3
# ⬇️ 507489_archi_gunshot_scifi_09.flac.mp3
# ⬇️ 402791_AK47_and_various_other_gunshots_at_indoor_shooting_range.mp3
# ⬇️ 399270_Simple_Gunshot_Reverb_Test.wav.mp3
# ⬇️ 399268_Simple_Gunshot_Reverb_Test.wav.mp3
# ⬇️ 399267_Simple_Gunshot_Reverb_Test.wav.mp3
# ⬇️ 399266_Simple_Gunshot_Reverb_Test.wav.mp3
# ⬇️ 402014_gunshot__high_6.wav.mp3
# ⬇️ 402013_gunshot__high_4.wav.mp3
# ⬇️ 402010_gunshot__high_1.wav.mp3
# ⬇️ 402009_gunshot__high_2.wav.mp3
# ⬇️ 396015_Silenced_Gunshot_4.wav.mp3
# ⬇️ 405132_gunshots.wav.mp3
# ⬇️ 404816_Gunshot.wav.mp3
# ⬇️ 407662_Gunshot.mp3
# ⬇️ 353093_SFX_Pistol_Gunshot.mp3
# ⬇️ 324585_MALFOY_Florian_2015_2016_Gunshot.wav.mp3
# ⬇️ 341255_Gunshot00.wav.mp3
# ⬇️ 128293_Layered_Gunshot_3.WAV.mp3
# ⬇️ 341258_Gunshot01.wav.mp3
# ⬇️ 803497_Pocket_Pistol_gunshot_2_(Outside_of_room).mp3
# ⬇️ 803495_Pocket_Pistol_gunshot_2_(indoor).mp3
# ⬇️ 803494_Pocket_Pistol_gunshot_1_(indoor).mp3
# ⬇️ 767900_Gunshot_top_of_staircase.mp3
# ⬇️ 595048_gunshot.wav.mp3
# ⬇️ 518181_FX_-_Gunshot.mp3
# ⬇️ 767904_(VARIATION)_Gunshot_Stairs,_Door_closed.mp3
# ⬇️ 460851_GUNRif_M1_GARAND_GUNSHOT_MP.wav.mp3
# ⬇️ 548008_Rifle_Gunshot_Tail.mp3
# ⬇️ 682795_sampleable_retro_gunshot.mp3
# ⬇️ 136766_Gunshot001.mp3
# ⬇️ 133848_Gunshot.mp3
# ⬇️ 543234_gunshot.WAV.mp3
# ⬇️ 58241_1010_-_Gunshots2.wav.mp3
# ⬇️ 99789_Distant_Gunshot_(3_Round_Burst).aiff.mp3
# ⬇️ 157970_Cal_.9_Gunshot.mp3
# ⬇️ 157555_gunshot_explosion.mp3
# ⬇️ 258205_Tykit,_tykistö_ampuu,_tykistöammunta___Artillery_firing,_cannons_shooting_at_the_front,_echoing_gunshots,_mix.mp3
# ⬇️ 253436_Gunshot_#3.wav.mp3
# ⬇️ 654373_Rapid_Gunshots.wav.mp3
# ⬇️ 636114_gunshots_bb_gun.flac.mp3
# ⬇️ 734098_Gunshot_400m_Forest_High_Quality.mp3
# ⬇️ 734096_Forest_Impulse_Response_Gunshot_Tail.mp3
# ⬇️ 734093_Gunshot_500m_Pine_Forest_High_Quality.mp3
# ⬇️ 576966_Theatre_gunshot_studio_theatre_KOT_2.flac.mp3
# ⬇️ 569309_Saiga_12k_Gunshot(12ga).mp3.mp3
# ⬇️ 717591_220823_Gunshots,_stage_pistol,_Soulpepper,_R-07.mp3
# ⬇️ 708327_Gunshot_from_air_rifle_pellet_gun.mp3
# ⬇️ 764548_CZ_P09_Airsoft_Gunshot.mp3
# ⬇️ 344142_Gunshot_002.wav.mp3
# ⬇️ 396191_Gunshot_during_the_night_in_Port-au-Prince_(Haïti).mp3
# ⬇️ 391328_Single_Pistol_Gunshot_4.wav.mp3
# ⬇️ 387589_crickets_gunshots_chimes_traffic.mp3
# ⬇️ 380185_Silenced_Gunshot_2.wav.mp3
# ⬇️ 368805_Gunshot_open_area_.wav.mp3
# ⬇️ 366776_AirRifleGunshot.wav.mp3
# ⬇️ 216319_Gunshot_07.wav.mp3
# ⬇️ 425349_8bit_gunshot_44_auto.wav.mp3
# ⬇️ 734097_Gunshot_Forest_2m_Harsh.mp3
# ⬇️ 235678_gunshot.wav.mp3
# ⬇️ 320130_Ase,_laukauksia_ulkona___Guns,_single_various_gunshots,_shots_with_hits,_echo,_ricochets,_exterior.mp3
# ⬇️ 632112_fran_freesound_gunshots_distance.wav.mp3
# ⬇️ 711703_Gunfire,_gunshot.mp3
# ⬇️ 687397_22LR_Gunshot.mp3.mp3
# ⬇️ 685039_gunshot_fx.wav.mp3
# ⬇️ 402789_Small_pistol_gunshot_indoors.mp3
# ⬇️ 432606_Distant_Gunshot.mp3
# ⬇️ 315858_gunshot_ricochet.aiff.mp3
# ⬇️ 332934_Tykki,_laukaus_ja_kaiku___Big_gun,_cannon,_155_mm,_shot,_gunshot_2_x,_a_long,_hefty_echo_.mp3
# ⬇️ 337241_Distant_Gunshot_(Three_Round_Burst).mp3
# ⬇️ 797452_gunshot.mp3
# ⬇️ 255264_Kivääri,_kaikuvia_laukauksia_ulkona,_kooste___A_rifle_or_two,_echoing,_solid_shots,_exterior,_mix.mp3
# ⬇️ 693856_KAC_LAMG.wav.mp3
# ⬇️ 693547_HK51.wav.mp3
# ⬇️ 692584_SIG_Sauer_SIG716.mp3.mp3
# ⬇️ 692209_Blaser_Tactical_2.mp3
# ⬇️ 413099_gunshort06.wav.mp3
# ⬇️ 413098_gunshort07.wav.mp3
# ⬇️ 413095_gunshort02.wav.mp3
# ⬇️ 333501_Gun_Shoot_3.mp3
# ⬇️ 333500_Gun_Shoot_4.mp3
# ⬇️ 333499_Gun_Shoot_5.mp3
# ⬇️ 333498_Gun_Shoot_7.mp3
# ⬇️ 333494_Gun_Shoot_2.mp3
# ⬇️ 790332_vengine_03.mp3
# ⬇️ 790331_vengine_02.mp3
# ⬇️ 790330_vengine_01.mp3
# ⬇️ 790329_shotgun_003.mp3
# ⬇️ 790328_shotgun_002.mp3
# ⬇️ 790327_shotgun_001.mp3
# ⬇️ 790326_fire_003.mp3
# ⬇️ 620853_Ray_Gun_A-06-A.mp3
# ⬇️ 620852_Ray_Gun_A-06-B.mp3
# ⬇️ 620851_Ray_Gun_A-07-A.mp3
# ⬇️ 620850_Ray_Gun_A-07-B.mp3
# ⬇️ 620849_Ray_Gun_A-13-B.mp3
# ⬇️ 620848_Ray_Gun_A-13-A.mp3
# ⬇️ 620847_Ray_Gun_A-11-B.mp3
# ⬇️ 620846_Ray_Gun_A-11-A.mp3
# ⬇️ 620845_Ray_Gun_A-12-B.mp3
# ⬇️ 620844_Ray_Gun_A-12-A.mp3
# ⬇️ 620842_Ray_Gun_A-05-A.mp3
# ⬇️ 620841_Ray_Gun_A-05-B.mp3
# ⬇️ 620840_Ray_Gun_A-03-A.mp3
# ⬇️ 620839_Ray_Gun_A-03-B.mp3
# ⬇️ 620838_Ray_Gun_A-04-A.mp3
# ⬇️ 620837_Ray_Gun_A-04-B.mp3
# ⬇️ 620836_Ray_Gun_A-01-A.mp3
# ⬇️ 620835_Ray_Gun_A-01-B.mp3
# ⬇️ 620834_Ray_Gun_A-02-A.mp3
# ⬇️ 620833_Ray_Gun_A-02-B.mp3
# ⬇️ 640697_distant_firework_boom.wav.mp3
# ⬇️ 674360_FlareGun_Blank01.wav.mp3
# ⬇️ 520046_Grenade_Cycle_Reload_03.wav.mp3
# ⬇️ 520043_Grenade_Mag_Open_04.wav.mp3
# ⬇️ 520042_Grenade_Mag_Open_03.wav.mp3
# ⬇️ 520041_Grenade_Fire_Eplosion_07.wav.mp3
# ⬇️ 520040_Grenade_Fire_Eplosion_06.wav.mp3
# ⬇️ 520039_Grenade_Mag_Open_02.wav.mp3
# ⬇️ 520035_Grenade_Bullet_Shell_Drop_01.wav.mp3
# ⬇️ 520031_Gadget_Alarm_Loop.wav.mp3
# ⬇️ 520029_Grenade_Blank_Fire_02.wav.mp3
# ⬇️ 520028_Grenade_Blank_Fire_03.wav.mp3
# ⬇️ 493876_ZM_098A_S03.wav.mp3
# ⬇️ 493875_ZM_098A_S04.wav.mp3
# ⬇️ 492300_ZM_057A_S01.wav.mp3
# ⬇️ 492299_ZM_057A_S02.wav.mp3
# ⬇️ 492298_ZM_197B_S05.wav.mp3
# ⬇️ 492297_ZM_197B_S06.wav.mp3
# ⬇️ 492296_ZM_197C_S01.wav.mp3
# ⬇️ 492295_ZM_197C_S02.wav.mp3
# ⬇️ 492294_ZM_197B_S01.wav.mp3
# ⬇️ 492293_ZM_197B_S02.wav.mp3
# ⬇️ 492292_ZM_197B_S03.wav.mp3
# ⬇️ 492291_ZM_197B_S04.wav.mp3
# ⬇️ 492290_ZM_197C_S03.wav.mp3
# ⬇️ 492289_ZM_197C_S04.wav.mp3
# ⬇️ 492288_ZM_157B_S06.wav.mp3
# ⬇️ 492287_ZM_157B_S05.wav.mp3
# ⬇️ 492286_ZM_157B_S04.wav.mp3
# ⬇️ 492285_ZM_157B_S03.wav.mp3
# ⬇️ 492284_ZM_177A_S04.wav.mp3
# ⬇️ 492283_ZM_177A_S03.wav.mp3
# ⬇️ 492282_ZM_177A_S02.wav.mp3
# ⬇️ 492281_ZM_177A_S01.wav.mp3
# ⬇️ 492280_ZM_177A_S06.wav.mp3
# ⬇️ 492279_ZM_177A_S05.wav.mp3
# ⬇️ 492278_ZM_097A_S01.wav.mp3
# ⬇️ 492277_ZM_097A_S02.wav.mp3
# ⬇️ 492276_ZM_077B_S05.wav.mp3
# ⬇️ 492275_ZM_077B_S06.wav.mp3
# ⬇️ 492274_ZM_077B_S03.wav.mp3
# ⬇️ 492273_ZM_077B_S04.wav.mp3
# ⬇️ 492272_ZM_077B_S01.wav.mp3
# ⬇️ 492271_ZM_077B_S02.wav.mp3
# ⬇️ 492270_ZM_097A_S03.wav.mp3
# ⬇️ 492269_ZM_097A_S04.wav.mp3
# ⬇️ 440663_Spaceship_Blaster.mp3
# ⬇️ 440662_Heavy_Blaster.mp3
# ⬇️ 440660_Light_Blaster_Weapon.mp3
# ⬇️ 440659_Rikochet_V1_Light_3.mp3
# ⬇️ 440658_Rikochet_V2_Medium_1.mp3
# ⬇️ 440657_Rikochet_V2_Medium_2.mp3
# ⬇️ 440656_Rikochet_V2_Medium_3.mp3
# ⬇️ 440655_Heavy_Spaceship_Blaster.mp3
# ⬇️ 440653_Rikochet_V1_Light_1.mp3
# ⬇️ 440652_Rikochet_V1_Light_2.mp3
# ⬇️ 435399_Several_shots_very_windy_conditions3.wav.mp3
# ⬇️ 435398_Several_shots_very_windy_conditions4.wav.mp3
# ⬇️ 435397_Several_shots_very_windy_conditions5.wav.mp3
# ⬇️ 435396_Close_range_shots_with_wind1.wav.mp3
# ⬇️ 435395_Close_range_shots_with_wind2.wav.mp3
# ⬇️ 435394_Close_range_shots_with_wind3.wav.mp3
# ⬇️ 435393_Several_shots_very_windy_conditions.wav.mp3
# ⬇️ 699578_M1895_Lee_Navy_Shot_(4).ogg.mp3
# ⬇️ 520051_Grenade_Fire_03.wav.mp3
# ⬇️ 520049_Grenade_Fire_Eplosion_02.wav.mp3
# ⬇️ 790335_vengine_04.mp3
# ⬇️ 212683_Firework_Explosion_3.mp3
# ⬇️ 520050_Grenade_Fire_Eplosion_01.wav.mp3
# ⬇️ 764550_CZ_P09_Reload_and_Slide_Release.mp3
# ⬇️ 618995_Gun_Silencer_2.mp3.mp3
# ⬇️ 699576_M1895_Lee_Navy_Shot_(2).ogg.mp3
# ⬇️ 212684_Firework_Explosion_4.mp3
# ⬇️ 440668_Laser_Impact.mp3
# ⬇️ 620858_Ray_Gun_A-10-B.mp3
# ⬇️ 620859_Ray_Gun_A-10-A.mp3
# ⬇️ 764551_CZ_P09_reload.mp3
# ⬇️ 699790_P38_Shot_(7).ogg.mp3
# ⬇️ 692587_Smith_&_Wesson_M&P_9_Exterior.wav.mp3
# ⬇️ 520053_Grenade_Fire_Eplosion_04.wav.mp3
# ⬇️ 520034_Grenade_Bullet_Shell_Drop_02.wav.mp3
# ⬇️ 440654_SciFi_Blaster.mp3
# ⬇️ 729121_Alien_Weapon_Shotgun_.mp3
# ⬇️ 460852_GUNRif_M1_GARAND_DRY_FIRE_MP.wav.mp3
# ⬇️ 435405_Two_close_range_shots.wav.mp3
# ⬇️ 440667_Medium_Blaster.mp3
# ⬇️ 435411_Side_by_side_multiple_shooters.wav.mp3
# ⬇️ 620857_Ray_Gun_A-08-A.mp3
# ⬇️ 366466_paintballgun_shots.wav.mp3
# ⬇️ 319009_Shotgun-Far.mp3.mp3
# ⬇️ 191230_AK_47_ft._Tommy_Gun_loop.wav.mp3
# ⬇️ 674376_FlareGun_Shot02.wav.mp3
# ⬇️ 790334_xdrone_02.mp3
# ⬇️ 699787_P38_Shot_(4).ogg.mp3
# ⬇️ 699579_M1895_Lee_Navy_Shot_(5).ogg.mp3
# ⬇️ 520037_Grenade_Bullet_Shell_Drop_05.wav.mp3
# ⬇️ 640700_distant_firework_boom_2.wav.mp3
# ⬇️ 745278_Killing_sound_for_movies.mp3
# ⬇️ 752590_complejo_impulsivo-shot.mp3
# ⬇️ 388255_21_Gun_Salute.mp3.mp3
# ⬇️ 388197_Slam_&_Fire.wav.mp3
# ⬇️ 212679_Firework_Explosions_Distance_1.mp3
# ⬇️ 348670_Shotgun_A3.wav.mp3
# ⬇️ 333503_Gun_Shoot_8.mp3
# ⬇️ 473689_Balloons_popping.mp3
# ⬇️ 466311_Air_Rifle_Unedited.mp3
# ⬇️ 500929_Night_of_New_Year's_Eve.mp3
# ⬇️ 413102_gunshort09.wav.mp3
# ⬇️ 411689_RifleFire.wav.mp3
# ⬇️ 399067_Sako30-06_1.wav.mp3
# ⬇️ 319008_Shotgun-Close-Load&Unload.mp3.mp3
# ⬇️ 260600_50_cal_and_.223_short.wav.mp3
# ⬇️ 37789_BREAKIN.wav.mp3
# ⬇️ 46656_carbine.wav.mp3
# ⬇️ 46655_carbine_single.wav.mp3
# ⬇️ 67019_submachinegun.wav.mp3
# ⬇️ 59488_Civil_Destruction.wav.mp3
# ⬇️ 240855_Shotgun_Slight_Mountain_Reverb.mp3
# ⬇️ 783910_Machine_Gun_Sound.mp3
# ⬇️ 701224_Welrod_suppresed_pistol.mp3
# ⬇️ 621155_Reload_-_Escopeta_M7.wav.mp3
# ⬇️ 621151_Reload_Gun_M7.wav.mp3
# ⬇️ 621150_Shotgun.wav.mp3
# ⬇️ 620854_Ray_Gun_A-09-B.mp3
# ⬇️ 620077_Metal_Impact.mp3
# ⬇️ 608388_Last_Known_Recording.Wav.mp3
# ⬇️ 636024_WEAPONMachineGun_Rifle,_Burst_Fire,3Shots_JW-48kHz-Stereo.wav.mp3
# ⬇️ 636023_WEAPONPistol_Cyberpistol,_Lazer,_Sci-fi_JW-48kHz-Stereo.wav.mp3
# ⬇️ 569847_Gun_Shot_#1.mp3
# ⬇️ 645778_Arming_a_Sci-Fi_Gun.mp3
# ⬇️ 645318_M1014_shot_extracted.wav.mp3
# ⬇️ 645317_M9_noisegate-17.80.wav.mp3
# ⬇️ 658858_Shoot.mp3
# ⬇️ 685391_Generic_Hand_Gun_Gun_Shot_With_Mag_Insert,_Cocking,_Firing,_Bullet_drops.mp3
# ⬇️ 685878_Click_-_Sound_Effect_(HD).mp3.mp3
# ⬇️ 399065_Tikka_M65_2.wav.mp3
# ⬇️ 415508_RPK_Kalashnikov_'s_hand_machine_gun.mp3
# ⬇️ 427598_AR15_pistol_shot.mp3
# ⬇️ 427597_AR15_rifle_shot_from_50_yards_away.mp3
# ⬇️ 427594_22_magnum_pistol_shot.mp3
# ⬇️ 395454_beretta_92_slow_motion.wav.mp3
# ⬇️ 408733_shooting_a_shotgun.wav.mp3
# ⬇️ 345584_Pistooli,_laukauksia___Old_pistol,_a_few_shots,_exterior.mp3
# ⬇️ 344192_toy-pistol.wav.mp3
# ⬇️ 319010_Shotgun-Close.mp3.mp3
# ⬇️ 331240_Plasma_Rifle_Gun_Shots_-_Various.mp3
# ⬇️ 320132_Kivääri,_kaikuvia_laukauksia_ulkona___A_rifle,_7,62_calibre,_echoing,_single_shots_at_a_distance,_also_ricochets,_exteriorv.mp3
# ⬇️ 274559_Auto_Machine_Gun.wav.mp3
# ⬇️ 338321_End_of_WWII_on_Elba_-_Soviets_Celebrating.wav.mp3
# ⬇️ 578193_gunfire_help_identify_weapon_ak47_shotgun_pistol_long_gun_4.mp3
# ⬇️ 810978_TOOLPneu-Samsung_Galaxy_Smartphone_Nail_Gun,_Burst_03_Nicholas_Judy_TDC.mp3
# ⬇️ 804825_gun_shot.mp3
# ⬇️ 804823_gun_reload.mp3
# ⬇️ 807403_slabfall_1.mp3
# ⬇️ 764954_308._calliber_gun_shots.mp3
# ⬇️ 766083_Burst_Pistol.mp3
# ⬇️ 766066_AR15_Rifle_Fire.mp3
# ⬇️ 361136_Attack_Pack_FX1.mp3
# ⬇️ 564124_1866_WW1_machine_gun_free_sound_FX_Cinematic_Sound_Effects.mp3.mp3
# ⬇️ 556367_Fuse_and_small_Explosion.mp3
# ⬇️ 523404_22_caliber_gunfire_with_ricochet.wav.mp3
# ⬇️ 523403_22_caliber_with_ricochet.wav.mp3
# ⬇️ 541818_Weapon_Revolver_Shots_Stereo.wav.mp3
# ⬇️ 34708_44_black_powder.wav.mp3
# ⬇️ 660770_Hit_Impact.mp3
# ⬇️ 440665_Recreated_Star_Wars_Blaster.mp3
# ⬇️ 202725_Rocket_Launcher.wav.mp3
# ⬇️ 621156_Reload_Shotgun_Escopeta_M7-13.wav.mp3
# ⬇️ 538302_Authentic_M60_Firing.mp3.mp3
# ⬇️ 187119_unfa's_Laser_Weapon_Sounds.mp3
# ⬇️ 267893_Bullet_Hit_Metal.mp3
# ⬇️ 543929_Pistol_Gun_Magazine_Reload.mp3
# ⬇️ 702672_Remington_870.mp3
# ⬇️ 595494_OWI_Gun_shot.wav.mp3
# ⬇️ 342184_BigGun.wav.mp3
# ⬇️ 232867_357_Magnum_Ext_2_shots_Empty_Chamber_Clicks.wav.mp3
# ⬇️ 346904_Revolver_calibre_38_-_vários_disparos_01.mp3
# ⬇️ 102586_Sounds_of_the_Australian_Bush.mp3
# ⬇️ 150837_Bullet_Impact_1.mp3
# ⬇️ 162432_Rossi-Revolver_96kHz-24bit.wav.mp3
# ⬇️ 165478_Gun_Battle_Short.wav.mp3
# ⬇️ 165393_Machine_Gun_Shots_Fast.mp3
# ⬇️ 162435_Uzi-single_96kHz-24bit.wav.mp3
# ⬇️ 351778_AK47_SFX.mp3.mp3
# ⬇️ 346906_Revolver_calibre_38_-_vários_disparos_02.mp3
# ⬇️ 427596_AR15_rifle_shot.mp3
# ⬇️ 81455_fireworks_launch_denoised.wav.mp3
# ⬇️ 84254_45_Smith_&_Wesson.wav.mp3
# ⬇️ 674361_FlareGun_Blank02.wav.mp3
# ⬇️ 457044_Slow_Motion_Gun_Shot.mp3
# ⬇️ 710305_[SEMI-RAW]_P38_AC42_Shot_(1).mp3
# ⬇️ 699789_P38_Shot_(6).ogg.mp3
# ⬇️ 676588_Colt_SMG_-_Firing,_Handling.mp3
# ⬇️ 640698_distant_firework_boom_4.wav.mp3
# ⬇️ 734060_DD_Shotgun_2c.mp3
# ⬇️ 732127_Epic_Shotgun_Blast,_Reverb,_80s_Style.mp3
# ⬇️ 254772_Gun_shot.wav.mp3
# ⬇️ 376816_Impact.mp3
# ⬇️ 320742_Complex_Minigun_Spin-Up_Firing.mp3
# ⬇️ 645316_snub_nose_357_magnum_noisegate-17.80.wav.mp3
# ⬇️ 718175_Shotgun_Fire_1.mp3
# ⬇️ 504175_Tsamp7_Te_Papa_Door_Slam.wav.mp3
# ⬇️ 365256_gun_shot.wav.mp3
# ⬇️ 619041_Shot_Gun_-_12_Gauge-_Fire_Four_Shots_Quickly.mp3
# ⬇️ 240944_laser.on_off.kawabunga.wav.mp3
# ⬇️ 198121_Man_Getting_Shot.wav.mp3
# ⬇️ 186049_Shotgun_Shooting_Things.wav.mp3
# ⬇️ 456266_Grad_BM-21_MLRS.wav.mp3
# ⬇️ 452540_increasingly_flangy_bangs.flac.mp3
# ⬇️ 452154_Rifle_Shots.mp3
# ⬇️ 443130_DOIZY_HADRIEN_2018_2019_GatesOfTheUnderworld.wav.mp3
# ⬇️ 177014_Artillery_Drone_Cadmium.wav.mp3
# ⬇️ 177011_Artillery_Drone_Banana_Yellow.wav.mp3
# ⬇️ 177012_Artillery_Drone_Aureoline.wav.mp3
# ⬇️ 260587_Electronic_snare.wav.mp3
# ⬇️ 361258_8-bit_Snare_or_Impact.mp3
# ⬇️ 82019_Distant_Hunt_With_Shots.wav.mp3
# ⬇️ 244769_Fireworks-Crowd.flac.mp3
# ⬇️ 43659_20071104.forest.00.mp3.mp3
# ⬇️ 381992_USP_Pistol_SFX.wav.mp3
# ⬇️ 528041_Horror_Synth_1.mp3
# ⬇️ 438858_G55-04-Cannon_Wind.wav.mp3
# ⬇️ 369526_Balloon_Pop_Studio_(2).wav.mp3
# ⬇️ 147038_Gun_Talk.mp3.mp3
# ⬇️ 177016_Artillery_Drone_Burnt_Orange.wav.mp3
# ⬇️ 396327_SemiAutoRifle3.mp3
# ⬇️ 369525_Balloon_Pop_Studio_(3).wav.mp3
# ⬇️ 449434_Small_bomb_with_hit.mp3
# ⬇️ 721431_new_Barrett.mp3
# ⬇️ 720118_Player_Shoot1.mp3
# ⬇️ 369527_Balloon_Pop_Studio_(1).wav.mp3
# ⬇️ 417601_Laser_Gun_Shot.mp3
# ⬇️ 432900_portazo.wav.mp3
# ⬇️ 426462_frogs_01.flac.mp3
# ⬇️ 397370_forest_gun_shots_and_gunfire.mp3
# ⬇️ 396326_SemiAutoRifle2.mp3
# ⬇️ 404562_AssaultRifle1.wav.mp3
# ⬇️ 404561_AssaultRifle2.wav.mp3
# ⬇️ 387481_empty-gun-failure-to-fire-trigger-pull-2.mp3
# ⬇️ 317074_Storm_and_thunder.mp3
# ⬇️ 274745_Shots_in_the_woods.wav.mp3
# ⬇️ 329716_Gun_shot.mp3
# ⬇️ 542205_Balloon_Pops.wav.mp3
# ⬇️ 528262_Silenced_Shot.mp3
# ⬇️ 611396_loudinsdrumstrial.wav.mp3
# ⬇️ 546832_Distant_Fireworks.wav.mp3
# ⬇️ 467397_MnG_-_BioMech_Shot.wav.mp3
# ⬇️ 514464_Explosion_Synthetic_with_wind_(MSfxP7_-_61_4).mp3
# ⬇️ 466834_enhanced_blaster.wav.mp3
# ⬇️ 465006_Laser_energy_gun_shot_blasts.mp3
# ⬇️ 495786_Noise_dist_shot_(2lrs,Eq,Ovrdr)1.wav.mp3
# ⬇️ 393732_AR15_M4_Gun_Hardware_Magazine_Movement_Sounds.mp3
# ⬇️ 384708_Woodland_Ambience.mp3.mp3
# ⬇️ 378204_Semi-Auto_Rifle_Shot_(Open_Field_Mixed).mp3
# ⬇️ 244770_Fireworks.flac.mp3
# ⬇️ 184992_Head_Slam.L.aif.mp3
# ⬇️ 528042_Horror_Synth_2.mp3
# ⬇️ 397657_MachineGunloop.wav.mp3
# ⬇️ 617001_Wind_Turbine.wav.mp3
# ⬇️ 530162_Light_explosion_near_in_forest.flac.mp3
# ⬇️ 32587_20070318.forest.00.wav.mp3
# ⬇️ 536636_Gunshot_03.sse.wav.mp3
# ⬇️ 650643_Gunshot.wav.mp3
# ⬇️ 467755_gunshot.wav.mp3
# ⬇️ 542549_Gunshot_Revolver_22.wav.mp3
# ⬇️ 262436_Real_explosions_Real_gunshots.wav.mp3
# ⬇️ 218481_GunShot01.mp3.mp3
# ⬇️ 244138_9mm_gunshot.wav.mp3
# ⬇️ 764601_Gunshots.mp3
# ⬇️ 37237_Gun-Shot_Gun(2_pumps).wav.mp3
# ⬇️ 742583_Sci-Fi_Gunshot_-_Heavy_Blast_Weapon.mp3
# ⬇️ 107621_GunShot.04.wav.mp3
# ⬇️ 107619_GunShot.02.wav.mp3
# ⬇️ 162365_Navy_Battleship_Soundscape:_Turret_Gunshots,_Mechanical_Engine_Humm,_Radio_Chatter,_Officer_Command_Voices.flac.mp3
# ⬇️ 164667_Gunshot_1.wav.mp3
# ⬇️ 36815_gunshots.mp3.mp3
# ⬇️ 85571_Ext-amb_empty-open-field_distant-gunshot.aif.mp3
# ⬇️ 463159_Disparo_(Gunshot).mp3
# ⬇️ 653057_Lo_Fi_12-bit_Nova_Gun_Rounds_Gunshots_Shooter_Shells_Rifle_Old_Converter_Etx_-_Nova_Sound.mp3.mp3
# ⬇️ 384685_Silenced_Gunshot_3.wav.mp3
# ⬇️ 218487_GunShot03.mp3.mp3
# ⬇️ 653058_Lo_Fi_12-bit_Nova_Gun_Rounds_Gunshots_Shooter_Shells_Rifle_Old_Converter_-_Nova_Sound.wav.mp3
# ⬇️ 218480_GunShot02.mp3.mp3
# ⬇️ 365905_SAURY_Jade_2016_2017_Gunshot.wav.mp3
# ⬇️ 166493_Silenced_Gun_Firing_-_gunshots.mp3
#
# 🔎 Hledám: rifle
# ⬇️ 682037_FN_FAL_Rifle_Unload_02.mp3.mp3
# ⬇️ 682036_FN_FAL_Rifle_Unload_01.mp3.mp3
# ⬇️ 682034_FN_FAL_Rifle_Load_02.mp3.mp3
# ⬇️ 682033_FN_FAL_Rifle_Load_01.mp3.mp3
# ⬇️ 501556_3030_Rifle_Ejecting_Spent_Casing.wav.mp3
# ⬇️ 43752_308_rifle_03_100yds_dwnrng02.wav.mp3
# ⬇️ 43751_308_rifle_01.wav.mp3
# ⬇️ 43403_rifle_steel_plate_multiple_ricochettes.mp3.mp3
# ⬇️ 43379_rifle_steel_plate.mp3.mp3
# ⬇️ 19514_22_rifle_02.wav.mp3
# ⬇️ 682031_FN_FAL_Rifle_Unload_and_Cock.mp3.mp3
# ⬇️ 682030_FN_FAL_Rifle_Load_and_Cock_02.mp3.mp3
# ⬇️ 682029_FN_FAL_Rifle_Load_and_Cock_01.mp3.mp3
# ⬇️ 682028_Dragunov_SVD_Rifle_Load;_Weapons_1.mp3
# ⬇️ 682027_Dragunov_SVD_Rifle_Load;_Weapons.mp3
# ⬇️ 682026_Dragunov_SVD_Rifle_Load_Empty;_Weapons_1.mp3
# ⬇️ 682025_Dragunov_SVD_Rifle_Load_Empty;_Weapons.mp3
# ⬇️ 682017_H&K_416_Assault_Rifle_Mechan;_Empty_Mag_Inserted_Into_And_Pulled_Out.mp3
# ...
# ⬇️ 351899_coffee_shop.wav.mp3
# ⬇️ 251960_Freeway_Traffic.mp3
# ⬇️ 394162_Porta.wav.mp3
# ⬇️ 562206_881_(2010)_Aerologic_(DHL)_Boeing_777-FZN_D-AALF_LEJ26L_06-03-2021.wav.mp3
# ⬇️ 535353_Wheeldumper.wav.mp3
# ⬇️ 568095_IR_artisan_garage_B2_03_balloon_stereo.mp3
# ⬇️ 575233_Formando_Jeguinho_no_Parque_dos_Cajueiros.mp3
# ⬇️ 764570_Telephone.mp3
# ⬇️ 764534_Blowgun.mp3
# ⬇️ 688690_dental_floss_sounds.wav.mp3
# ⬇️ 729064_plastic_tape_2.0.mp3
# ⬇️ 729063_plastic_tape.mp3
# ⬇️ 720858_METLMvmt-Big_Tor_Rolling_Stool,_Shaking_01_RG_2023_NTG4.mp3
# ⬇️ 761066_Rusty_metal_tools.mp3
# ⬇️ 767450_Som_de_folhas_de_galho.mp3
# ⬇️ 765463_Paintbrush_on_Canvas.mp3
# ⬇️ 765461_Underpainting_v2.mp3
# ⬇️ 765426_Hand_fidgeting_inside_the_bowl_of_plastics.mp3
# ⬇️ 418716_TH_SFX_-_Subtle_metal_rattles_and_knocks_01.wav.mp3
# ⬇️ 418707_TH_SFX_-_Metal_Deep_Slam_01.wav.mp3
# ⬇️ 432596_daisy63_lawnmower_close.wav.mp3
# ⬇️ 402093_diamonds_in_a_bag.wav.mp3
# ⬇️ 442367_slow_creepy_door_creaks.wav.mp3
# ⬇️ 442361_plastic_pegs_rattle.wav.mp3
# ⬇️ 442360_metallic_punch.wav.mp3
# ⬇️ 442344_Deep_thud_punch.wav.mp3
# ⬇️ 491299_borcegos_sobre_piso_de_madera.WAV.mp3
# ⬇️ 491077_Metal_nail_falling.mp3
# ⬇️ 486591_Drinking_Tea_(ASMR).mp3
# ⬇️ 128258_Breaking_Dish_1.aif.mp3
# ⬇️ 166607_water_boiler_boiling.wav.mp3
# ⬇️ 199961_Brume_criquets_Sillery_septembre.A1_01.wav.mp3
# ⬇️ 189282_Amb_Hipica_+_Renill.wav.mp3
# ⬇️ 231770_PineWarblerSequenceMarch30th2014-1.mp3.mp3
# ⬇️ 180680_creakydoor.mp3.mp3
# ⬇️ 49295_BARCO_MUELLE_OMAN.wav.mp3
# ⬇️ 34861_Weight_Scale_Off.aif.mp3
# ⬇️ 60853_muddy.wav.mp3
# ⬇️ 49297_MOTOR_BOTE_OMAN.wav.mp3
# ⬇️ 25451_03_dogwalk_(new_2).wav.mp3
# ⬇️ 17816_water.wav.mp3
# ⬇️ 94699_Outdoor_Car_Door.wav.mp3
# ⬇️ 105009_feedback.wav.mp3
# ⬇️ 49302_MAR_OMAN.wav.mp3
# ⬇️ 49301_MAR_FUERTE_OMAN.wav.mp3
# ⬇️ 49300_GRILLOS_OMAN.wav.mp3
# ⬇️ 49299_CAÑON_AVES_OMAN.wav.mp3
# ⬇️ 49296_GAVIOTAS_OMAN.wav.mp3
# ⬇️ 231539_Florida_Grand_Prix_in_the_streets_of_St._Petersburg,_Florida.mp3
# ⬇️ 276286_Shore_recording.wav.mp3
# ⬇️ 246276_Elevator_Sounds_#1.wav.mp3
# ⬇️ 246275_Engine_Roar_#1.wav.mp3
# ⬇️ 246273_Glass_Crunching_#1.wav.mp3
# ⬇️ 246272_Canoga_Park_Traffic_#1.wav.mp3
# ⬇️ 246271_Carwash_Sounds_#1.wav.mp3
# ⬇️ 246270_Crosswalk_Beeping_with_Effects.wav.mp3
# ⬇️ 245168_Rusty_Sheet_Metal.wav.mp3
# ⬇️ 245106_San_Francisco_Boat_Yard.wav.mp3
# ⬇️ 245105_San_Francisco_Shore_Birds.wav.mp3
# ⬇️ 245104_Large_Couch_Falling_Off_Balcony.wav.mp3
# ⬇️ 245103_Small_Couch_Falling_Off_Balcony.wav.mp3
# ⬇️ 243740_Bike_Riding_Sounds_#1.wav.mp3
# ⬇️ 243739_Bike_Riding_Sounds_#2.wav.mp3
# ⬇️ 243737_Faucet_Sounds_#1.wav.mp3
# ⬇️ 243736_Toilet_Sounds_#1.wav.mp3
# ⬇️ 243734_Fireworks_#1.wav.mp3
# ⬇️ 243733_Fireworks_#2.wav.mp3
# ⬇️ 243732_Water_Fountain_#1.wav.mp3
# ⬇️ 243403_Amtrak_Train_Sounds_#1.wav.mp3
# ⬇️ 243402_Amtrak_Train_Sounds_#2.wav.mp3
# ⬇️ 243401_Train_Startion_Ambience.wav.mp3
# ⬇️ 243025_Dirt_&_Rocks_Footsteps_SFX_#3.wav.mp3
# ⬇️ 243024_Large_Door_#1.wav.mp3
# ⬇️ 689699_Rain_in_a_rural_neighborhood.wav.mp3
# ⬇️ 688951_Fountain.mp3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 39
#      37         continue
#      38     print(f"⬇️ {safe_name}")
# ---> 39     urllib.request.urlretrieve(preview_url, path)
#      40     downloaded_ids.add(sound.id)
#      41 except Exception as e:
#
# File /usr/lib/python3.10/urllib/request.py:241, in urlretrieve(url, filename, reporthook, data)
#     224 """
#     225 Retrieve a URL into a temporary location on disk.
#     226
#    (...)
#     237 data file as well as the resulting HTTPMessage object.
#     238 """
#     239 url_type, path = _splittype(url)
# --> 241 with contextlib.closing(urlopen(url, data)) as fp:
#     242     headers = fp.info()
#     244     # Just return the local path and the "headers" for file://
#     245     # URLs. No sense in performing a copy unless requested.
#
# File /usr/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File /usr/lib/python3.10/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File /usr/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /usr/lib/python3.10/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File /usr/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346 try:
#    1347     try:
# -> 1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
#
# File /usr/lib/python3.10/http/client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1280 def request(self, method, url, body=None, headers={}, *,
#    1281             encode_chunked=False):
#    1282     """Send a complete request to the server."""
# -> 1283     self._send_request(method, url, body, headers, encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1325 if isinstance(body, str):
#    1326     # RFC 2616 Section 3.7.1 says that text default has a
#    1327     # default charset of iso-8859-1.
#    1328     body = _encode(body, 'body')
# -> 1329 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276 else:
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 msg = b"\r\n".join(self._buffer)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#    1043     if hasattr(message_body, 'read'):
#    1044         # Let file-like take precedence over byte-like.  This
#    1045         # is needed to allow the current position of mmap'ed
#    1046         # files to be taken into account.
#
# File /usr/lib/python3.10/http/client.py:976, in HTTPConnection.send(self, data)
#     974 if self.sock is None:
#     975     if self.auto_open:
# --> 976         self.connect()
#     977     else:
#     978         raise NotConnected()
#
# File /usr/lib/python3.10/http/client.py:1448, in HTTPSConnection.connect(self)
#    1445 def connect(self):
#    1446     "Connect to a host on a given (SSL) port."
# -> 1448     super().connect()
#    1450     if self._tunnel_host:
#    1451         server_hostname = self._tunnel_host
#
# File /usr/lib/python3.10/http/client.py:942, in HTTPConnection.connect(self)
#     940 """Connect to the host and port specified in __init__."""
#     941 sys.audit("http.client.connect", self, self.host, self.port)
# --> 942 self.sock = self._create_connection(
#     943     (self.host,self.port), self.timeout, self.source_address)
#     944 # Might fail in OSs that don't implement TCP_NODELAY
#     945 try:
#
# File /usr/lib/python3.10/socket.py:845, in create_connection(address, timeout, source_address)
#     843 if source_address:
#     844     sock.bind(source_address)
# --> 845 sock.connect(sa)
#     846 # Break explicitly a reference cycle
#     847 err = None
#
# KeyboardInterrupt:

# %%
#FILTER

import os
import shutil
from pydub.utils import mediainfo
from pydub import AudioSegment

INPUT_DIR = "freesound_gunshots"
REJECTED_DIR = "freesound_gunshots/REJECTED"
os.makedirs(REJECTED_DIR, exist_ok=True)

# Nastavení filtrů
MIN_DURATION = 0.1   # v sekundách
MAX_DURATION = 3.0   # v sekundách
BAD_KEYWORDS = ["metal", "drum", "clap", "kick", "throw", "crowd", "hit", "loop", "sample", "whoosh", "slam"]

# Seznam všech .mp3 souborů
files = [f for f in os.listdir(INPUT_DIR) if f.endswith(".mp3")]

rejected_count = 0

for file in files:
    path = os.path.join(INPUT_DIR, file)
    try:
        audio = AudioSegment.from_file(path)
        duration = len(audio) / 1000.0  # v sekundách
        name_lower = file.lower()

        # Filtr: špatná délka nebo podezřelé slovo
        if duration < MIN_DURATION or duration > MAX_DURATION or any(bad in name_lower for bad in BAD_KEYWORDS):
            print(f"🚫 Filtruji: {file} ({duration:.2f}s)")
            shutil.move(path, os.path.join(REJECTED_DIR, file))
            rejected_count += 1

    except Exception as e:
        print(f"❌ Chyba při zpracování {file}: {e}")

print(f"\n✅ Hotovo! Odstraněno {rejected_count} špatných souborů.")
# Out:
# 🚫 Filtruji: 570304_gun_II:_Car_Machine_Gun_Overheat..mp3 (7.11s)
# 🚫 Filtruji: 86346_Lark_with_MG.aif.mp3 (17.64s)
# 🚫 Filtruji: 342238_Rocket.wav.mp3 (6.85s)
# 🚫 Filtruji: 712555_krinkov-aks74u-parts_disassembling_and_assembling.mp3 (14.37s)
# 🚫 Filtruji: 414023_Realistic_Gun-Fire.mp3 (4.45s)
# 🚫 Filtruji: 392226_Single_Gunshot_6.2_HP.wav.mp3 (3.29s)
# 🚫 Filtruji: 445111_Airsoft_Rifle_Mag_change.mp3 (11.09s)
# 🚫 Filtruji: 678527_Gunshots_Rifle.mp3 (5.27s)
# 🚫 Filtruji: 675602_S20-46_On_the_receiving_end_of_a_50_cal_Browning_machine_gun.wav.mp3 (6.68s)
# 🚫 Filtruji: 675670_S18-21_Rifle_shots.wav.mp3 (4.18s)
# 🚫 Filtruji: 201669_AK47_down_the_block.aif.mp3 (3.42s)
# 🚫 Filtruji: 513353_Shotgun_Being_Loaded2.mp3.mp3 (7.43s)
# 🚫 Filtruji: 182052_Arctic_Shooting_Training_[FpR3Ni1LSBg].flac.mp3 (10.71s)
# 🚫 Filtruji: 320132_Kivääri,_kaikuvia_laukauksia_ulkona___A_rifle,_7,62_calibre,_echoing,_single_shots_at_a_distance,_also_ricochets,_exteriorv.mp3 (32.15s)
# 🚫 Filtruji: 626221_dog_toy_glass_bowl.wav.mp3 (9.78s)
# 🚫 Filtruji: 655173_OWI_Airsoft_Pistol_Shots.wav.mp3 (10.50s)
# 🚫 Filtruji: 574332_Reloading.wav.mp3 (12.63s)
# 🚫 Filtruji: 698687_270_Calibre_Gunshot.wav.mp3 (4.00s)
# 🚫 Filtruji: 505199_British303EmptyCaseEject.wav.mp3 (13.82s)
# 🚫 Filtruji: 37903_20070722.ambiance.pinewood.passing.plane.mp3.mp3 (609.70s)
# 🚫 Filtruji: 564310_Thermal_Sniper_shot_2.wav.mp3 (3.26s)
# 🚫 Filtruji: 681616_Fn_F2000_Assault_Rifle_5.56Mm._Belgium._Mechan;_Empty_Mag_Inserted_Into_And_Pulled_Out.mp3.mp3 (23.24s)
# 🚫 Filtruji: 492790_Walking_on_leaves_recorded_with_Rode_Shotgun_Microphone_post-processed_in_Reaper.wav.mp3 (9.50s)
# 🚫 Filtruji: 507703_Hit_3_8_Bit.wav.mp3 (1.19s)
# 🚫 Filtruji: 707550_Outside_Bathroom_ambience.wav.mp3 (242.51s)
# 🚫 Filtruji: 594018_Break_Action_Toy_gun_reloaded_multiple_times._Recorded_with_a_Zoom_H6_recorder_in_a_large_room..wav.mp3 (10.48s)
# 🚫 Filtruji: 707527_Hand_Saw.wav.mp3 (9.98s)
# 🚫 Filtruji: 416417_Automatic_Assault_Rifle.wav.mp3 (12.63s)
# 🚫 Filtruji: 196753_shooting_in_the_forest.mp3.mp3 (10.01s)
# 🚫 Filtruji: 417345_Gunshot,_Distant,_A.wav.mp3 (4.85s)
# 🚫 Filtruji: 94696_Hammer.wav.mp3 (7.83s)
# 🚫 Filtruji: 507704_Hit_2_8_Bit.wav.mp3 (0.55s)
# 🚫 Filtruji: 408434_Heart_Beat.wav.mp3 (19.65s)
# 🚫 Filtruji: 707535_Shovel_in_dirt_(angry).wav.mp3 (10.37s)
# 🚫 Filtruji: 779238_Handling_machine_gun_and_ammos,_putting_on_strap.mp3 (56.00s)
# 🚫 Filtruji: 557513_Sci-fi_rifle_weapon_shot_3_(14lrs,mltprcssng).wav.mp3 (3.73s)
# 🚫 Filtruji: 539153_double-flangy_remix_of_Erokia's_freesound_#538858.flac.mp3 (69.33s)
# 🚫 Filtruji: 34708_44_black_powder.wav.mp3 (21.97s)
# 🚫 Filtruji: 515195_rifle,_assault_rifle_mp5,_semiautomatic_mode,_rappid_shots.mp3 (6.07s)
# 🚫 Filtruji: 418961_Space_SFX_#8_-_Machine_Gun_or_Generator.mp3.mp3 (4.13s)
# 🚫 Filtruji: 445108_Airsoft_Gun_Shots.mp3 (8.71s)
# 🚫 Filtruji: 518181_FX_-_Gunshot.mp3 (25.82s)
# 🚫 Filtruji: 342953_Clip_out_-_draw_from_bag_-_slide_across_-_gun_-_Clipin.mp3 (5.23s)
# 🚫 Filtruji: 581772_Reload_and_shoot_HZA_01-08-2021.wav.mp3 (3.34s)
# 🚫 Filtruji: 655772_Nature_Reserve_Hiking_Trail.mp3.mp3 (136.00s)
# 🚫 Filtruji: 460848_GUNMech_M1_GARAND_CLIP_EJECT_MP.wav.mp3 (5.50s)
# 🚫 Filtruji: 653398_9mm_Glock_Gen_Five_shooting.wav.mp3 (4.50s)
# 🚫 Filtruji: 327499_Garden_Ambience_01_OWI.wav.mp3 (90.84s)
# 🚫 Filtruji: 653430_Mossberg_590_12_Gauge_Shooting.wav.mp3 (5.50s)
# 🚫 Filtruji: 647905_Gun_Cocking_Sounds.wav.mp3 (8.53s)
# 🚫 Filtruji: 724944_Shooting_a_Shotgun_-_NT1A_-_With_Tail.mp3 (5.72s)
# 🚫 Filtruji: 149795_Pistols_Handguns_manipulated_and_toyed_with.mp3 (169.21s)
# 🚫 Filtruji: 385846_Battle_Sound_Effects_~_Siren,_Storm,_Vocals,_Explosions.mp3.mp3 (112.22s)
# 🚫 Filtruji: 327513_Starting_and_turning_off_lawnmower_OWI.wav.mp3 (14.12s)
# 🚫 Filtruji: 766062_45mm_Pistol.mp3 (5.56s)
# 🚫 Filtruji: 460852_GUNRif_M1_GARAND_DRY_FIRE_MP.wav.mp3 (3.10s)
# 🚫 Filtruji: 184360_Sniper_Shots_&_Reload.flac.mp3 (24.00s)
# 🚫 Filtruji: 609668_Reload_Pistol_Slide.mp3.mp3 (4.85s)
# 🚫 Filtruji: 564483_Shotgun_hit.mp3 (0.49s)
# 🚫 Filtruji: 70094_Dramatic_triple_metal_clang_1_stylised_gunfire.wav.mp3 (12.81s)
# 🚫 Filtruji: 427597_AR15_rifle_shot_from_50_yards_away.mp3 (3.89s)
# 🚫 Filtruji: 391631_Sci-Fi_Rifle.mp3 (3.00s)
# 🚫 Filtruji: 562868_throwing_stuff_in_dumpster_sounds_like_gunshots.mp3 (26.22s)
# 🚫 Filtruji: 675646_S19-14_Exterior_pistol_shots_with_long_reverb.wav.mp3 (7.57s)
# 🚫 Filtruji: 589847_Taurus_G2c_Uncut_Foley.mp3 (188.44s)
# 🚫 Filtruji: 46656_carbine.wav.mp3 (14.43s)
# 🚫 Filtruji: 486056_R11-50-Cocking_Rifle.wav.mp3 (15.22s)
# 🚫 Filtruji: 406226_Gun_handling_near_mono.wav.mp3 (9.73s)
# 🚫 Filtruji: 96892_Change_Rattle.mp3.mp3 (8.28s)
# 🚫 Filtruji: 71339_Parabolix_candy_flavored_bullets_intro_with_machine_gun_now_even_less_bullets.wav.mp3 (12.74s)
# 🚫 Filtruji: 535353_Wheeldumper.wav.mp3 (29.96s)
# 🚫 Filtruji: 327133_Closing_zip_of_guitar_bag_OWI.wav.mp3 (11.00s)
# 🚫 Filtruji: 77246_Mauser_3.08_2.wav.mp3 (3.86s)
# 🚫 Filtruji: 231243_Desert_Eagle_.50.mp3 (3.21s)
# 🚫 Filtruji: 507702_Hit_4_8_Bit.wav.mp3 (1.40s)
# 🚫 Filtruji: 372590_Nerf_Reload_and_Noises.wav.mp3 (40.49s)
# 🚫 Filtruji: 677160_Uzi_submachine_gun_being_reloaded_while_empty._Full_sequence.mp3 (4.00s)
# 🚫 Filtruji: 234520_weapon1.wav.mp3 (9.39s)
# 🚫 Filtruji: 324476_Paintball_gun_fire.mp3 (15.50s)
# 🚫 Filtruji: 585623_Felixstowe_beach_waves_close_shotgun_3min_stereo_reverb.wav.mp3 (181.00s)
# 🚫 Filtruji: 90448_Screw_Boxes.mp3.mp3 (20.19s)
# 🚫 Filtruji: 276957_awp_reload_sound_2.mp3.mp3 (4.31s)
# 🚫 Filtruji: 516036_Gun_Sounds.mp3 (10.09s)
# 🚫 Filtruji: 349087_Muffled_warfare.mp3 (84.24s)
# 🚫 Filtruji: 386821_RailGun_-_Single.wav.mp3 (6.00s)
# 🚫 Filtruji: 57948_bottle1.wav.mp3 (59.13s)
# 🚫 Filtruji: 486053_R30-43-Rapid-Fire_Machine_Gun.wav.mp3 (36.26s)
# 🚫 Filtruji: 655755_Pool_Game_Opening.mp3.mp3 (4.50s)
# 🚫 Filtruji: 492774_Cat_meow_recorded_with_Rode_Shotgun_Microphone_post-processed_in_Reaper.wav.mp3 (7.10s)
# 🚫 Filtruji: 675633_S25-12_Spinning_the_cylinder_of_a_pistol_for_Russian_Roulette.wav.mp3 (13.82s)
# 🚫 Filtruji: 326680_Pellet_Gun.wav.mp3 (9.85s)
# 🚫 Filtruji: 241733_San_Francisco_City_Sounds_#3.wav.mp3 (387.66s)
# 🚫 Filtruji: 65694_playinglong.wav.mp3 (1043.87s)
# 🚫 Filtruji: 187677_M16_Rifle_Shots.flac.mp3 (7.92s)
# 🚫 Filtruji: 435394_Close_range_shots_with_wind3.wav.mp3 (3.08s)
# 🚫 Filtruji: 210901_Three_cannon_shots.mp3 (8.12s)
# 🚫 Filtruji: 548628_gunshot.wav.mp3 (12.09s)
# 🚫 Filtruji: 675596_S06-01_Machine_gun_bursts_with_echo.wav.mp3 (19.13s)
# 🚫 Filtruji: 370344_Pump_Action_Shotgun_Cycle.mp3 (11.14s)
# 🚫 Filtruji: 384689_20170318.gunshot.paradiso.wav.mp3 (24.99s)
# 🚫 Filtruji: 171211_Dry_Fire.mp3 (3.13s)
# 🚫 Filtruji: 423928_Futuristic_Ballistic_Rifle.mp3 (11.25s)
# 🚫 Filtruji: 494403_gun_shots.wav.mp3 (55.56s)
# 🚫 Filtruji: 677279_vibrations_plastic_b.wav.mp3 (11.27s)
# 🚫 Filtruji: 633234_Random_sci-fi_sounds.mp3 (14.96s)
# 🚫 Filtruji: 552536_Glockenspiel_Glock.mp3 (4.46s)
# 🚫 Filtruji: 186049_Shotgun_Shooting_Things.wav.mp3 (9.76s)
# 🚫 Filtruji: 119958_doorbell_for_unwelcome_visitors_#2.flac.mp3 (15.00s)
# 🚫 Filtruji: 367344_Pistol_Magazine_injection_and_ejection.WAV.mp3 (36.18s)
# 🚫 Filtruji: 528041_Horror_Synth_1.mp3 (10.37s)
# 🚫 Filtruji: 407715_Pistol_Cocking_(BB_Gun).mp3 (10.72s)
# 🚫 Filtruji: 329557_FXLM_cups_dishes_kitchen_close_rattling_shaking_tinkling_earthquake_vari_M.wav.mp3 (6.90s)
# 🚫 Filtruji: 618038_Toy_magnets_scraping_and_snapping_together_-_gun_foley.mp3 (18.21s)
# 🚫 Filtruji: 245106_San_Francisco_Boat_Yard.wav.mp3 (230.27s)
# 🚫 Filtruji: 39067_cannon.round.wav.mp3 (5.31s)
# 🚫 Filtruji: 655752_Construction_Drilling.mp3.mp3 (11.99s)
# 🚫 Filtruji: 728093_Hole_puncher_movement_and_handling_sound.mp3 (138.24s)
# 🚫 Filtruji: 1518_RMX_UpDownBit5(Loop).wav.mp3 (1.10s)
# 🚫 Filtruji: 661727_Gunshot;_Metallic.wav.mp3 (1.06s)
# 🚫 Filtruji: 423112_Guns_&_Explosions_Album_-_Computer_explosion_6_-_Alarm.wav.mp3 (9.92s)
# 🚫 Filtruji: 698476_AL3.0_Hammer_Double_Action_Pull.ogg.mp3 (0.09s)
# 🚫 Filtruji: 443095_ARBEZ_Guillaume_2018_2019_WalkRobot.wav.mp3 (11.66s)
# 🚫 Filtruji: 556367_Fuse_and_small_Explosion.mp3 (5.70s)
# 🚫 Filtruji: 523381_Edge_summer_forest_Roond_NL_200619_0186.ogg.mp3 (3630.22s)
# 🚫 Filtruji: 214220_World's_'longest-echo'_6th_impulse.mp3 (81.20s)
# 🚫 Filtruji: 163687_REME_soldiers_training_Hankley_Common.mp3 (203.36s)
# 🚫 Filtruji: 387190_Pump_Action_Shotgun.mp3 (5.46s)
# 🚫 Filtruji: 655771_Pocketing_a_Pool_Ball.mp3.mp3 (7.92s)
# 🚫 Filtruji: 514037_blaster_shot_4(Sytrus,rsmpl,2lrs,multiprcsng)single.wav.mp3 (4.57s)
# 🚫 Filtruji: 724943_Shooting_a_Shotgun_-_MKH50_-_With_Tail.mp3 (5.67s)
# 🚫 Filtruji: 514668_12_manipulando_arma.wav.mp3 (6.00s)
# 🚫 Filtruji: 486073_R23-27-Rifle_Blast.wav.mp3 (4.59s)
# 🚫 Filtruji: 681674_IMI_Galil_Assault_Rifle_Mechan;_Empty_Mag_Inserted_Into_And_Pulled_Out.mp3.mp3 (43.72s)
# 🚫 Filtruji: 19938_Nascar-TMS-1998-2.wav.mp3 (72.32s)
# 🚫 Filtruji: 86246_Various_Shotgun_Pumps.aif.mp3 (7.71s)
# 🚫 Filtruji: 689699_Rain_in_a_rural_neighborhood.wav.mp3 (229.85s)
# 🚫 Filtruji: 807665_08_-_Weaponry_-_Ultra-Heavy_Cannon_B.mp3 (3.25s)
# 🚫 Filtruji: 514074_Robo_gun_(Sytrus,rsmpl,multiprcsng)serial.wav.mp3 (15.09s)
# 🚫 Filtruji: 514659_25_recargar_arma.wav.mp3 (12.00s)
# 🚫 Filtruji: 767308_EQUIPTact_Leather_Revolver_Holster_Equip_HvD_OwSFX.mp3 (14.84s)
# 🚫 Filtruji: 77727_Gunfire_in_the_distance_01.wav.mp3 (294.13s)
# 🚫 Filtruji: 435402_Several_shots_very_windy_conditions6.wav.mp3 (12.60s)
# 🚫 Filtruji: 523715_PDR_AMB,_01._fireworks,_neighbourhood,_zoomH6_stereo_shotgun.wav.mp3 (382.70s)
# 🚫 Filtruji: 561464_Gun_Hammer_Click.wav.mp3 (3.14s)
# 🚫 Filtruji: 426462_frogs_01.flac.mp3 (574.34s)
# 🚫 Filtruji: 67587_mute_gun_shot_1.flac.mp3 (0.05s)
# 🚫 Filtruji: 557514_Sci-fi_rifle_weapon_shot_2-1_(17lrs,mltprcssng).wav.mp3 (4.60s)
# 🚫 Filtruji: 407520_Paper_shredder.wav.mp3 (20.00s)
# 🚫 Filtruji: 260738_Gun_Reloads.mp3 (14.40s)
# 🚫 Filtruji: 249884_AR15_Outdoor_Echo.mp3.mp3 (41.65s)
# 🚫 Filtruji: 432491_Industrial_factory_working.mp3 (868.78s)
# 🚫 Filtruji: 563391_Laser_gun_sound.mp3 (56.00s)
# 🚫 Filtruji: 237273_Assault_Rifle_Shooting.wav.mp3 (5.02s)
# 🚫 Filtruji: 166515_SRS_Cinematic_Hit.mp3 (6.94s)
# 🚫 Filtruji: 411584_HaloNeedler_AltFar.wav.mp3 (3.81s)
# 🚫 Filtruji: 491651_Blowing_Nose_into_Tissues,_Recorded_on_Rode_Shotgun_Mini,_Post_processed_in_Reaper.mp3 (4.50s)
# 🚫 Filtruji: 128157_Rifle_Cartridges_clanging.mp3.mp3 (20.45s)
# 🚫 Filtruji: 257876_LHS_Gunshots.wav.mp3 (5.26s)
# 🚫 Filtruji: 205901_Machine_gun_firing_(blanks._In_studio_shoot).wav.mp3 (38.00s)
# 🚫 Filtruji: 162431_Shotgun_96kHz-24bit.wav.mp3 (6.55s)
# 🚫 Filtruji: 428679_Single_cricket_up_close.mp3 (24.50s)
# 🚫 Filtruji: 568095_IR_artisan_garage_B2_03_balloon_stereo.mp3 (7.78s)
# 🚫 Filtruji: 568007_249_single_shot.wav.mp3 (22.10s)
# 🚫 Filtruji: 474125_M134_Minigun_Firing.wav.mp3 (11.26s)
# 🚫 Filtruji: 507482_archi_gunshot_scifi_03.flac.mp3 (8.00s)
# 🚫 Filtruji: 259707_car_over_frozen_snow_ice_002_141228_0475_MS.wav.mp3 (26.38s)
# 🚫 Filtruji: 259718_car_over_frozen_snow_ice_003_141228_0475_MS.wav.mp3 (132.48s)
# 🚫 Filtruji: 37789_BREAKIN.wav.mp3 (5.66s)
# 🚫 Filtruji: 540066_Weapon_Revolver_DryFire_Mono.wav.mp3 (3.13s)
# 🚫 Filtruji: 408439_Rattling_fridge.wav.mp3 (14.29s)
# 🚫 Filtruji: 371199_Bullet_Shells_Thrown_In_Basket.wav.mp3 (0.34s)
# 🚫 Filtruji: 747476_BLLTShel_Falling_.223_On_Metal_Surface_03_KVV_AUDIO_FREE.mp3 (1.35s)
# 🚫 Filtruji: 445576_Paint_can_dropping_on_carpet.wav.mp3 (6.16s)
# 🚫 Filtruji: 386780_Machine_Gun_Shooting.wav.mp3 (4.08s)
# 🚫 Filtruji: 164937_Shotgun_Firing_with_Casings.mp3 (28.49s)
# 🚫 Filtruji: 100166_raw_tincan_airpistol_plink.mp3.mp3 (131.34s)
# 🚫 Filtruji: 688702_performative_DVD_disc_extraction_(shotgun_mic).wav.mp3 (95.55s)
# 🚫 Filtruji: 486063_R12-09-Rifle_Shots,_Natural_Reverb.wav.mp3 (54.89s)
# 🚫 Filtruji: 367348_Pumpaction_shotgun.WAV.mp3 (40.88s)
# 🚫 Filtruji: 41607_shell.wav.mp3 (33.14s)
# 🚫 Filtruji: 468068_Industrial_crane_movement.mp3 (14.98s)
# 🚫 Filtruji: 639160_NL_AIRSOFT_GLOCK_17_BB_HANDLING_04.wav.mp3 (4.02s)
# 🚫 Filtruji: 241737_San_Francisco_City_Sounds_#5.wav.mp3 (266.09s)
# 🚫 Filtruji: 445237_Firework_2.mp3 (5.00s)
# 🚫 Filtruji: 159707_Mossberg_500A_-_1_shot_and_echo_alt.mp3 (3.24s)
# 🚫 Filtruji: 243733_Fireworks_#2.wav.mp3 (231.97s)
# 🚫 Filtruji: 655731_Airsoft_Sniper_Shooting.mp3.mp3 (0.01s)
# 🚫 Filtruji: 327135_Crunching_Potato_Chips_into_glass_Bowl_OWI.wav.mp3 (11.00s)
# 🚫 Filtruji: 693768_Kidričevo_-_shooting_range.wav.mp3 (269.32s)
# 🚫 Filtruji: 514073_Robo_gun_cinematic(Sytrus,rsmpl,multiprcsng,echo)serial.wav.mp3 (10.02s)
# 🚫 Filtruji: 263764_08092014_Torzym_warszawska_street.mp3.mp3 (48.65s)
# 🚫 Filtruji: 263753_08092014_Torzym_children_on_the_street.mp3.mp3 (106.89s)
# 🚫 Filtruji: 148829_.223_targetside.mp3.mp3 (3.48s)
# 🚫 Filtruji: 693691_zak.mp3.mp3 (9.58s)
# 🚫 Filtruji: 427396_Plasma_-_Lazer_Pistol_Gun_Shot_1.mp3 (5.84s)
# 🚫 Filtruji: 675008_AK-47_assault_rifle_being_cocked_3x.mp3 (6.33s)
# 🚫 Filtruji: 266420_bird_in_the_Hague_at_dawn_4.wav.mp3 (169.59s)
# 🚫 Filtruji: 49971_TEC9_Cart_Montage.aif.mp3 (9.00s)
# 🚫 Filtruji: 619029_Hand_Gun_-_38_Cal.,_Police_Service_Revolver,_6_Fast_Shots.mp3 (4.27s)
# 🚫 Filtruji: 49296_GAVIOTAS_OMAN.wav.mp3 (58.30s)
# 🚫 Filtruji: 486021_R12-12-Large_Gun_in_Metal_Bunker.wav.mp3 (6.01s)
# 🚫 Filtruji: 621152_Shotgun_cocking_AT.wav.mp3 (0.07s)
# 🚫 Filtruji: 566262_FirstSniperShotLine.wav.mp3 (5.50s)
# 🚫 Filtruji: 717585_220816_Gunshot2,_stage_pistol,_Soulpepper,_R-07.mp3 (6.78s)
# 🚫 Filtruji: 764519_AR15_Airsoft_Jam_Fix.mp3 (6.76s)
# 🚫 Filtruji: 101961_Heavy_machine_gun.wav.mp3 (13.13s)
# 🚫 Filtruji: 640699_distant_firework_boom_3.wav.mp3 (61.30s)
# 🚫 Filtruji: 415507_Kalashnikov_machine_gun_shoot_inside.mp3 (37.16s)
# 🚫 Filtruji: 675957_S25-10_Loading_cartridges_into_a_rifle.wav.mp3 (16.87s)
# 🚫 Filtruji: 65891_clicks_01.wav.mp3 (12.21s)
# 🚫 Filtruji: 658612_Pops_from_popping_air_pouches.mp3 (6.81s)
# 🚫 Filtruji: 418716_TH_SFX_-_Subtle_metal_rattles_and_knocks_01.wav.mp3 (13.34s)
# 🚫 Filtruji: 675630_S25-09_Loading_shotgun;_indoors.wav.mp3 (23.81s)
# 🚫 Filtruji: 256874_Railway-station_on_200m_MS__141124_0466.wav.mp3 (193.40s)
# 🚫 Filtruji: 105009_feedback.wav.mp3 (71.89s)
# 🚫 Filtruji: 90449_Tool_Box.mp3.mp3 (24.66s)
# 🚫 Filtruji: 241885_Joint_Popping_#1.wav.mp3 (24.01s)
# 🚫 Filtruji: 635944_Gun_Mag_Reload.wav.mp3 (4.29s)
# 🚫 Filtruji: 408099_Shotgun_Shot_02.wav.mp3 (3.20s)
# 🚫 Filtruji: 431838_Blaser_R8_close_shots_(clipped).wav.mp3 (6.60s)
# 🚫 Filtruji: 682042_Franchi_SPAS-12_Load_Shells.mp3 (12.50s)
# 🚫 Filtruji: 589843_Taurus_G2c_Safety_Switch.mp3 (6.35s)
# 🚫 Filtruji: 328621_machinegunatdistance.wav.mp3 (28.57s)
# 🚫 Filtruji: 675661_S20-03_Mountain_rifle_with_reverb.wav.mp3 (3.22s)
# 🚫 Filtruji: 442361_plastic_pegs_rattle.wav.mp3 (13.05s)
# 🚫 Filtruji: 147901_Gunshot.mp3.mp3 (3.00s)
# 🚫 Filtruji: 699171_Baby_Desert_Eagle_III_9mm_Dry_Fire_(2).ogg.mp3 (0.07s)
# 🚫 Filtruji: 767074_Sci-Fi_Rail_Gun.mp3 (17.95s)
# 🚫 Filtruji: 492770_Biting_something_crunchy_recorded_with_Rode_Shotgun_Microphone_post-processed_in_Reaper.wav.mp3 (5.86s)
# 🚫 Filtruji: 765393_Pulling_back_slide_on_an_airsoft_pistol.mp3 (10.00s)
# 🚫 Filtruji: 393651_Sniper_Rifle_Shot_Gun_Shot_(Outdoor_Close)_with_Bolt_Action_[Mixed].mp3 (3.59s)
# 🚫 Filtruji: 200277_Assault_Rifle_Loop_.mp3 (0.09s)
# 🚫 Filtruji: 406584_Suitcase_Packing_2_Muffled_Near_Mono.mp3 (21.93s)
# 🚫 Filtruji: 263768_11092014_torzym_open_window.mp3.mp3 (101.16s)
# 🚫 Filtruji: 34861_Weight_Scale_Off.aif.mp3 (6.87s)
# 🚫 Filtruji: 204949_m4-carbine_improved.wav.mp3 (24.20s)
# 🚫 Filtruji: 460847_GUNMech_M1_GARAND_CLIP_EJECT_2_MP.wav.mp3 (8.15s)
# 🚫 Filtruji: 327138_Dogs_Barking_OWI.wav.mp3 (12.00s)
# 🚫 Filtruji: 486064_R12-23-Sharp_Pistol_File_with_Reverb.wav.mp3 (11.60s)
# 🚫 Filtruji: 655774_Sword_Fighting.mp3.mp3 (8.14s)
# 🚫 Filtruji: 628274_Machine_War_2.mp3.mp3 (61.19s)
# 🚫 Filtruji: 611887_shotgun_moving_stones_in_stone_river1_Sierra_Albarracin_010921_David_Albanes_Bonillo_SONOTOMIA.wav.mp3 (30.76s)
# 🚫 Filtruji: 253437_Gunshot_#2.wav.mp3 (18.73s)
# 🚫 Filtruji: 85120_did_a_shotgun_shell_just_hit_the_floor.wav.mp3 (3.20s)
# 🚫 Filtruji: 523923_DontWorryAboutYourPistol.wav.mp3 (5.57s)
# 🚫 Filtruji: 683759_Plasma_Shot_sound_-_GSE_2_10.mp3 (6.85s)
# 🚫 Filtruji: 707534_Lawnmower_cutting_grass.wav.mp3 (24.99s)
# 🚫 Filtruji: 241086_Blackbird-01-Pocklington_canal-18jun2014.wav.mp3 (35.00s)
# 🚫 Filtruji: 201670_AK47_Fire_into_Street.aif.mp3 (5.21s)
# 🚫 Filtruji: 678880_AR15_Safety_Selector.mp3 (0.07s)
# 🚫 Filtruji: 488756_Pistole_-_Schlitten_schieben.wav.mp3 (10.12s)
# 🚫 Filtruji: 475420_Revolver_reloading_2(click,_gun,_pistol,_weapon,_metal).wav.mp3 (32.01s)
# 🚫 Filtruji: 674743_Browning_Hi-Power_handgun_having_its_magazine_removed_and_replaced_3x.mp3 (13.07s)
# 🚫 Filtruji: 553424_Gowanus_Scrap_Metal_Yard_-_Loading_Barge_2021-01-04_12-01.wav.mp3 (372.74s)
# 🚫 Filtruji: 363122_Landmass___Earth_Rumble.mp3 (9.06s)
# 🚫 Filtruji: 811818_Gun_Range.mp3 (631.33s)
# 🚫 Filtruji: 93966_Wood_shots.flac.mp3 (33.17s)
# 🚫 Filtruji: 581769_Machine_gun_2_HZA_01-08-2021.wav.mp3 (6.04s)
# 🚫 Filtruji: 198099_Shotgun_Snare_1.mp3 (3.01s)
# 🚫 Filtruji: 266383_bird_in_oostduinen_lake_10.wav.mp3 (18.00s)
# 🚫 Filtruji: 724518_Shotgun_Foley_1_[1lovewav].mp3 (24.91s)
# 🚫 Filtruji: 675655_S18-20_Big_optical_gun_shots_with_ricochets.wav.mp3 (6.71s)
# 🚫 Filtruji: 112074_loading_a_kimber_1911.mp3.mp3 (3.06s)
# 🚫 Filtruji: 719241_A_rifle_being_moved_around_and_rattled_constantly._Bright_sounding.mp3 (13.68s)
# 🚫 Filtruji: 100209_Humprecht.wav.mp3 (12.00s)
# 🚫 Filtruji: 438566_G35-02-Pistol_Shots.wav.mp3 (25.00s)
# 🚫 Filtruji: 698686_270_Calibre_Gunshot_-_With_Tail.wav.mp3 (4.00s)
# 🚫 Filtruji: 517774_Birds_In_High_Winds.wav.mp3 (91.52s)
# 🚫 Filtruji: 495786_Noise_dist_shot_(2lrs,Eq,Ovrdr)1.wav.mp3 (5.58s)
# 🚫 Filtruji: 677283_vibrations_cloth.wav.mp3 (13.95s)
# 🚫 Filtruji: 396324_HeavyMachineGun.wav.mp3 (36.48s)
# 🚫 Filtruji: 514058_blaster_shot_8_1(Sytrus,rsmpl,multiprcsng)single.wav.mp3 (6.38s)
# 🚫 Filtruji: 266384_bird_in_oostduinen_21.wav.mp3 (30.73s)
# 🚫 Filtruji: 37237_Gun-Shot_Gun(2_pumps).wav.mp3 (5.45s)
# 🚫 Filtruji: 423110_Guns_&_Explosions_Album_-_Explosion_8.wav.mp3 (12.00s)
# 🚫 Filtruji: 411583_HaloNeedler_AltMid.wav.mp3 (3.81s)
# 🚫 Filtruji: 616281_Fireworks,_display,_lots,_close,_popping,_no_echo_.stereo.wav.mp3 (39.50s)
# 🚫 Filtruji: 38298_20070722.pinar_0900am.flac.mp3 (240.00s)
# 🚫 Filtruji: 71324_Parabolix_candy_flavored_bullets_intro_with_machine_gun_now_less_bullets.wav.mp3 (13.05s)
# 🚫 Filtruji: 218484_MachineGunLoop.mp3.mp3 (0.59s)
# 🚫 Filtruji: 212602_Machine_Gun_001_-_loop.ogg.mp3 (0.30s)
# 🚫 Filtruji: 398597_pistol_shot_ricochet.wav.mp3 (10.00s)
# 🚫 Filtruji: 790974_GUNShotg_Hatsan_Bullpup_Pump_Action_01_KVV_AUDIO_FREE.mp3 (10.38s)
# 🚫 Filtruji: 243736_Toilet_Sounds_#1.wav.mp3 (119.45s)
# 🚫 Filtruji: 191775_gunshot.wav.mp3 (4.55s)
# 🚫 Filtruji: 40623_PigeonShooting.wav.mp3 (22.67s)
# 🚫 Filtruji: 348156_Pistol_Manipulation_02.wav.mp3 (6.56s)
# 🚫 Filtruji: 141572_M4A1_Reload.mp3 (21.45s)
# 🚫 Filtruji: 628273_Machine_War.mp3.mp3 (97.85s)
# 🚫 Filtruji: 741066_Diablo_12g_pistol_6_inch,_open_and_close_breech_4.mp3 (4.24s)
# 🚫 Filtruji: 708195_Straw_Broom_Sweeping:_Broom_sweeping_outside,_South_African_straw_broom,_sweeping_on_pavement._Recorded_with_ZoomH6,_with_rifle_microphone,_EQ_was_used_to_reduce_background_noise..mp3 (17.82s)
# 🚫 Filtruji: 414826_Gun_Version_2_without_forward_bolt.mp3 (5.86s)
# 🚫 Filtruji: 320742_Complex_Minigun_Spin-Up_Firing.mp3 (8.79s)
# 🚫 Filtruji: 128270_Sharp_hit.aif.mp3 (0.23s)
# 🚫 Filtruji: 707777_Baretta_22__pistol__shots_1.mp3 (5.75s)
# 🚫 Filtruji: 437070_Pistol_Reloading.mp3.mp3 (3.99s)
# 🚫 Filtruji: 584985_Twilight_Forest_(with_distant_gun_shots).mp3 (3855.64s)
# 🚫 Filtruji: 321217_Sci-Fi_Large_Machine_Power-Up.mp3 (4.84s)
# 🚫 Filtruji: 137044_telephone_bakelite_(w55)_dialing.wav.mp3 (16.14s)
# 🚫 Filtruji: 491630_Medicine_bottle_with_pills_inside_opening_and_closing__shaking_.wav.mp3 (52.50s)
# 🚫 Filtruji: 94697_House_Door_.wav.mp3 (9.96s)
# 🚫 Filtruji: 232274_Idle.wav.mp3 (6.80s)
# 🚫 Filtruji: 577278_Fireworks,_bangs_like_gunshots,_voices,_Stratford,_2011.wav.mp3 (7.93s)
# 🚫 Filtruji: 789848_Gun_moving.mp3 (10.49s)
# 🚫 Filtruji: 177013_Artillery_Drone_Carrot_Orange.wav.mp3 (14.00s)
# 🚫 Filtruji: 620934_Martini_MkIV_C_(handling).mp3 (11.05s)
# 🚫 Filtruji: 492778_Filing_recorded_with_Rode_Shotgun_Microphone_post-processed_in_Reaper.wav.mp3 (7.11s)
# 🚫 Filtruji: 492789_Trellidor_recorded_with_Rode_Shotgun_Microphone_post-processed_in_Reaper.wav.mp3 (4.20s)
# 🚫 Filtruji: 86055_Beam_Rifle.aif.mp3 (3.74s)
# 🚫 Filtruji: 396325_SemiAutoRifle1.mp3 (4.36s)
# 🚫 Filtruji: 764954_308._calliber_gun_shots.mp3 (15.40s)
# 🚫 Filtruji: 790332_vengine_03.mp3 (10.48s)
# 🚫 Filtruji: 674569_Browning_Hi-Power_handgun_being_reloaded_while_empty._Full_sequence.mp3 (4.25s)
# 🚫 Filtruji: 329526_FXLM_drone_quadrocopter_flying_close_T01_ssg.wav.mp3 (28.43s)
# 🚫 Filtruji: 55342_spencer.wav.mp3 (3.50s)
# 🚫 Filtruji: 514022_blaster_hit_1(Sytrus,rsmpl,multiprcsng)single.wav.mp3 (3.12s)
# 🚫 Filtruji: 327497_Office_Ambience_01_OWI.wav.mp3 (101.16s)
# 🚫 Filtruji: 320130_Ase,_laukauksia_ulkona___Guns,_single_various_gunshots,_shots_with_hits,_echo,_ricochets,_exterior.mp3 (34.77s)
# 🚫 Filtruji: 717584_220816_Gunshot,_stage_pistol,_Soulpepper,_R-07.mp3 (4.01s)
# 🚫 Filtruji: 480918_Sniper_Rifle_01.wav.mp3 (4.25s)
# 🚫 Filtruji: 766318_shotgun_shell_on_tiles.mp3 (27.57s)
# 🚫 Filtruji: 708196_Swords_Hitting_Each_Other:_2_Swords_clashing,_fighting_one_another,_hitting_each_other._Recorded_with_ZoomH6,_with_rifle_microphone,_EQ_was_used_to_reduce_background_noise..mp3 (14.04s)
# 🚫 Filtruji: 620935_SVT40_(canvas_backpack).mp3 (8.51s)
# 🚫 Filtruji: 162435_Uzi-single_96kHz-24bit.wav.mp3 (3.00s)
# 🚫 Filtruji: 176029_3_village_wangkou.wav.mp3 (29.94s)
# 🚫 Filtruji: 594358_Air_Rifle_Gun.mp3 (8.10s)
# 🚫 Filtruji: 766165_Gun_clicking_sound.mp3 (8.89s)
# 🚫 Filtruji: 507599_Metal_loops_80bpm_-_variation_5.mp3 (12.00s)
# 🚫 Filtruji: 507481_archi_gunshot_scifi_04.flac.mp3 (7.40s)
# 🚫 Filtruji: 514649_01_disparos_fondo.wav.mp3 (15.00s)
# 🚫 Filtruji: 741054_Diablo_12g_pistol_6_inch,_cocking_back_and_dry_fire_1.mp3 (4.35s)
# 🚫 Filtruji: 508970_car_passing_by.wav.mp3 (6.46s)
# 🚫 Filtruji: 445622_Shoe_polish_with_brush.wav.mp3 (21.57s)
# 🚫 Filtruji: 790972_GUNShotg_Hatsan_Bullpup_Dryfire_01_KVV_AUDIO_FREE.mp3 (5.12s)
# 🚫 Filtruji: 607057_Shotgun_Rifle_Magazine_Clip_Movement.mp3 (12.87s)
# 🚫 Filtruji: 205126_.30_Shell_Bouncing.mp3 (10.07s)
# 🚫 Filtruji: 434715_Toy_Gun_4.mp3 (5.87s)
# 🚫 Filtruji: 693734_Sci_Fi_Designed_Gunshot_5.mp3 (19.50s)
# 🚫 Filtruji: 83664_High_Caliber_Shells_Drop.wav.mp3 (15.88s)
# 🚫 Filtruji: 263755_08092014_Torzym_train_sound.mp3.mp3 (62.22s)
# 🚫 Filtruji: 706980_Realoding_a_30-30_Rifle._OWI.wav.mp3 (6.00s)
# 🚫 Filtruji: 366179_Glass_Beer_Bottle_Breaking_With_Rock.wav.mp3 (3.05s)
# 🚫 Filtruji: 708773_MGC_model_gun_attatching_barrel_and_detatching_barrel_sound.mp3 (10.00s)
# 🚫 Filtruji: 769901_Pistol.mp3 (33.75s)
# 🚫 Filtruji: 197320_9mm_Shot_in_the_Forest-Augmented_Attack.mp3 (40.65s)
# 🚫 Filtruji: 517771_Multiple_Birds_In_High_Winds.wav.mp3 (53.44s)
# 🚫 Filtruji: 755212_The_Cacophony_of_pain.MP3.mp3 (10.59s)
# 🚫 Filtruji: 542716_170339_Berno_Smit_Bolt_action_rifle_reloading_mechanism.wav.mp3 (25.32s)
# 🚫 Filtruji: 30990_shotgun.wav.mp3 (6.25s)
# 🚫 Filtruji: 491632_hubbly_bubbles.wav.mp3 (61.24s)
# 🚫 Filtruji: 65690_playingbalcony.wav.mp3 (48.00s)
# 🚫 Filtruji: 741071_Diablo_12g_pistol_6_inch,_open_breech,_close_breech_and_cock_back_3.mp3 (5.95s)
# 🚫 Filtruji: 408427_Alien_craft_moving.wav.mp3 (12.50s)
# 🚫 Filtruji: 17741_Babbling_Brook.wav.mp3 (15.45s)
# 🚫 Filtruji: 96031_Remix_task.wav.mp3 (100.17s)
# 🚫 Filtruji: 688864_Machine_Gun.wav.mp3 (4.78s)
# 🚫 Filtruji: 724945_Shooting_a_Shotgun_-_SM57_-_With_Tail.mp3 (5.55s)
# 🚫 Filtruji: 263756_08092014_Torzym_gymbus_in_front_of_school.mp3.mp3 (192.09s)
# 🚫 Filtruji: 187703_NERF_GUN_SHOOTING.flac.mp3 (17.11s)
# 🚫 Filtruji: 327519_Tearing_pages_out_of_a_book_OWI.wav.mp3 (12.32s)
# 🚫 Filtruji: 681492_AK47_Assault_Rifle_Mechan;_Empty_Mag_Inserted_Into_And_Pulled_Out.mp3 (46.07s)
# 🚫 Filtruji: 396271_Assault_Rifle_Manipulation_02.wav.mp3 (6.52s)
# 🚫 Filtruji: 387589_crickets_gunshots_chimes_traffic.mp3 (55.00s)
# 🚫 Filtruji: 190063_rifle_burst_4_secs.wav.mp3 (4.64s)
# 🚫 Filtruji: 34781_Water_Splash.aif.mp3 (17.05s)
# 🚫 Filtruji: 760469_Revolver_and_Shotgun_sounds.mp3 (21.45s)
# 🚫 Filtruji: 201668_M16_burst_in_street.aif.mp3 (4.17s)
# 🚫 Filtruji: 155654_Clay_pigeon_shooting_Rifle_near_Trutnov.mp3 (4.57s)
# 🚫 Filtruji: 528709_CP99_Reload.mp3 (3.19s)
# 🚫 Filtruji: 34982_glock17_02.wav.mp3 (45.15s)
# 🚫 Filtruji: 486044_R12-06-Machine_Gun_Single_Shots.wav.mp3 (14.14s)
# 🚫 Filtruji: 730595_DSGNSynth_ZAP_LARGE-Data_Sniper_BSL_LqdScifi.mp3 (24.00s)
# 🚫 Filtruji: 407518_Opening_A_Beer_and_drinking.wav.mp3 (13.00s)
# 🚫 Filtruji: 324386_08_Three_or_so_Whales.aif.mp3 (543.76s)
# 🚫 Filtruji: 155017_Bolt_Action_rifle_handling.mp3 (133.82s)
# 🚫 Filtruji: 765239_Gun_Cocking.mp3 (7.62s)
# 🚫 Filtruji: 707517_JigSaw_Startup_and_end.wav.mp3 (8.86s)
# 🚫 Filtruji: 681618_H&K_G36_Assault_Rifle_Cocks_and_Dryfire.mp3.mp3 (22.24s)
# 🚫 Filtruji: 733559_Rifling_through_a_purse_or_handbag_and_taking_out_a_piece_of_paper.mp3 (90.42s)
# 🚫 Filtruji: 466310_Air_Rifle.mp3 (3.47s)
# 🚫 Filtruji: 407523_Removing_a_stain_from_frabric.wav.mp3 (14.50s)
# 🚫 Filtruji: 653536_Riffle_shot_far.wav.mp3 (22.00s)
# 🚫 Filtruji: 435395_Close_range_shots_with_wind2.wav.mp3 (3.16s)
# 🚫 Filtruji: 671403_KidandmomtragicEvent.wav.mp3 (22.56s)
# 🚫 Filtruji: 578486_City_Square_Ambience.mp3 (1191.75s)
# 🚫 Filtruji: 784597_scifi_weapon_mechanism_sound_part_03_01062025.mp3 (13.46s)
# 🚫 Filtruji: 530162_Light_explosion_near_in_forest.flac.mp3 (6.26s)
# 🚫 Filtruji: 113360_Background_shooting_120.wav.mp3 (87.28s)
# 🚫 Filtruji: 486051_R30-20-Classic_Slow_Machine_Gun.wav.mp3 (19.05s)
# 🚫 Filtruji: 675124_S17-13_Barrage_with_shell_whines_and_heavy_machine_guns.wav.mp3 (47.73s)
# 🚫 Filtruji: 57946_bigbottle.wav.mp3 (139.51s)
# 🚫 Filtruji: 162434_Walter_P99_96kHz-24bit.wav.mp3 (3.36s)
# 🚫 Filtruji: 693732_Sci_Fi_Designed_Gunshot_3.mp3 (19.50s)
# 🚫 Filtruji: 714355_Flare_Pistol-_Burning_Flare.mp3 (6.09s)
# 🚫 Filtruji: 611907_shotgun_hangingBridge_Albarracin_300821_David_Albanes_Bonillo_SONOTOMIA.wav.mp3 (9.45s)
# 🚫 Filtruji: 546832_Distant_Fireworks.wav.mp3 (378.56s)
# 🚫 Filtruji: 513351_12_Gauge_Shotgun_Chamber_Round_Slowly.mp3.mp3 (9.29s)
# 🚫 Filtruji: 34859_Sink_Water_Turned_Off.aif.mp3 (15.31s)
# 🚫 Filtruji: 159701_Bryco_Arms_Model_38_-_7_shots_with_slight_shell_noise.mp3 (14.11s)
# 🚫 Filtruji: 264850_Hit_metal_pan_cover_bell_vibration_deep_2.mp3 (104.19s)
# 🚫 Filtruji: 741069_Diablo_12g_pistol_6_inch,_open_breech,_close_breech_and_cock_back_1.mp3 (5.07s)
# 🚫 Filtruji: 507602_Metal_loops_80bpm_-_variation_4.mp3 (12.00s)
# 🚫 Filtruji: 491662_Day_Time_Ambiance,_Birds,_Wind_sounds,_Ice-cream_Truck_Song_in_the_distance,_Recorded_on_Rode_Shotgun_Mini,_Post_processed_in_Reaper.mp3 (4.50s)
# 🚫 Filtruji: 655677_10.gun_cock.wav.mp3 (3.50s)
# 🚫 Filtruji: 700242_Dron_ASMR__-_Relaxing_Sounds_-_Hatsan_Shotgun_Escort_Marine_Guard_pump_action_sounds_02.mp3.mp3 (5.05s)
# 🚫 Filtruji: 365145_303_shells_being_handled_and_dropped_onto_tile_floor.wav.mp3 (7.43s)
# 🚫 Filtruji: 343680_RisingGunShot.wav.mp3 (6.27s)
# 🚫 Filtruji: 517772_Hard_Surface_Foot_Steps_In_High_Winds.wav.mp3 (16.26s)
# 🚫 Filtruji: 516745_Nerf_Hammershot_Dart_Shot.mp3 (7.50s)
# 🚫 Filtruji: 86104_PSS_Drum_Roll.wav.mp3 (0.69s)
# 🚫 Filtruji: 372184_Fake_rifle.wav.mp3 (5.32s)
# 🚫 Filtruji: 505196_Enfield_Loaded_With_2_Charger_Clips_Total_10_Rounds.wav.mp3 (45.77s)
# 🚫 Filtruji: 365146_303_rounds_being_put_into_bullet_holder_.wav.mp3 (31.20s)
# 🚫 Filtruji: 388198_Slam_&_Fire.mp3.mp3 (3.00s)
# 🚫 Filtruji: 571272_Two_Gunshots,_One_Body_Falling_(Outside).mp3 (5.54s)
# 🚫 Filtruji: 319008_Shotgun-Close-Load&Unload.mp3.mp3 (7.98s)
# 🚫 Filtruji: 94695_Gun_Cocking.wav.mp3 (4.49s)
# 🚫 Filtruji: 108044_20101031.shots.far.01.wav.mp3 (6.05s)
# 🚫 Filtruji: 434723_Toy_Gun_9_-_Warfare.mp3 (33.24s)
# 🚫 Filtruji: 189613_BassDrumMachineGun150.wav.mp3 (1.60s)
# 🚫 Filtruji: 620936_SVT40_(Handling).mp3 (5.75s)
# 🚫 Filtruji: 212967_Drilling_Bursts.mp3 (5.55s)
# 🚫 Filtruji: 620933_Starr_Revolver_(handling).mp3 (8.86s)
# 🚫 Filtruji: 795317_Revolver_Loading_-_Remington_1875.mp3 (7.59s)
# 🚫 Filtruji: 508745_Revolver_Dryfire.mp3 (33.62s)
# 🚫 Filtruji: 148839_9mm_gunside.mp3.mp3 (5.49s)
# 🚫 Filtruji: 698764_gun_pistol.wav.mp3 (11.92s)
# 🚫 Filtruji: 406583_Suitcase_Packing_Muffled_Near_Mono.mp3 (16.41s)
# 🚫 Filtruji: 231770_PineWarblerSequenceMarch30th2014-1.mp3.mp3 (32.42s)
# 🚫 Filtruji: 592173_forest_and_pitch_shifted_distant_guns.flac.mp3 (11.03s)
# 🚫 Filtruji: 367000_gun_shot.WAV.mp3 (4.94s)
# 🚫 Filtruji: 650643_Gunshot.wav.mp3 (9.91s)
# 🚫 Filtruji: 458873_gun_handling.flac.mp3 (21.13s)
# 🚫 Filtruji: 688690_dental_floss_sounds.wav.mp3 (50.48s)
# 🚫 Filtruji: 785315_Custom_Transformers_one_or_bumblebee_laser_sounds_01152025.mp3 (14.95s)
# 🚫 Filtruji: 445624_Elastic_band_snapping.wav.mp3 (8.63s)
# 🚫 Filtruji: 796560_Shotgun_Pumping_-_Winchester_1897_(Trench_Gun).mp3 (10.82s)
# 🚫 Filtruji: 651785_AR-15_-_firing_and_reload_sequence_with_reverb.mp3 (5.40s)
# 🚫 Filtruji: 327510_Closing_blinds_OWI.wav.mp3 (10.60s)
# 🚫 Filtruji: 764648_Reeds_in_a_Marshland_Ambience.mp3 (206.01s)
# 🚫 Filtruji: 240637_Seatbelt_Click.mp3 (3.33s)
# 🚫 Filtruji: 611906_shotgun_ambience_filter_hole_river_Albarracin_300821_David_Albanes_Bonillo_SONOTOMIA.wav.mp3 (37.14s)
# 🚫 Filtruji: 106732_Sci-Fi_Loop_1.wav.mp3 (3.17s)
# 🚫 Filtruji: 410370_Lännenelokuvan_tyylinen_pyssytaistelu____Western_movie_style_gunbattle.mp3 (30.28s)
# 🚫 Filtruji: 675595_S06-02_Machine_gun_bullets_hit_nearby;_ricochet.wav.mp3 (18.65s)
# 🚫 Filtruji: 675658_S05-19_Distant_rifle_shot_with_long_reverb.wav.mp3 (4.90s)
# 🚫 Filtruji: 731942_9mm_Pistol_Gunshots.mp3 (10.98s)
# 🚫 Filtruji: 707529_Screwdriver.wav.mp3 (17.76s)
# 🚫 Filtruji: 701049_Hunting_Rifle.mp3 (111.54s)
# 🚫 Filtruji: 394162_Porta.wav.mp3 (7.20s)
# 🚫 Filtruji: 259698_car_over_frozen_snow_ice_001_141228_0475_MS.wav.mp3 (28.99s)
# 🚫 Filtruji: 49297_MOTOR_BOTE_OMAN.wav.mp3 (47.77s)
# 🚫 Filtruji: 408426_Air_gun_reload.wav.mp3 (7.21s)
# 🚫 Filtruji: 595401_Paintball_gun_reloading_sound.wav.mp3 (24.29s)
# 🚫 Filtruji: 541164_Distant_Gunshot.mp3 (3.32s)
# 🚫 Filtruji: 235427_Semi-Auto_Rifle_Simulation.mp3 (14.22s)
# 🚫 Filtruji: 410551_Shotgun_kaliber_20_compressed_the_spike_by_12_dB_wav.mp3 (4.92s)
# 🚫 Filtruji: 395454_beretta_92_slow_motion.wav.mp3 (22.99s)
# 🚫 Filtruji: 148836_12gauge_gunside.mp3.mp3 (6.45s)
# 🚫 Filtruji: 2879_sonic_train_sample1.wav.mp3 (43.38s)
# 🚫 Filtruji: 456500_Freesound_2018_in_Sound,_by_Downloads.mp3 (1110.00s)
# 🚫 Filtruji: 22614_GRINDING_SHORE_SOUND.mp3_(2).mp3.mp3 (90.93s)
# 🚫 Filtruji: 2881_sonic_train_sample3.wav.mp3 (55.11s)
# 🚫 Filtruji: 91973_PJcalls2.wav.mp3 (15.00s)
# 🚫 Filtruji: 123223_Bullet_whiz_slowed.wav.mp3 (5.41s)
# 🚫 Filtruji: 562206_881_(2010)_Aerologic_(DHL)_Boeing_777-FZN_D-AALF_LEJ26L_06-03-2021.wav.mp3 (44.14s)
# 🚫 Filtruji: 460554_fountain_2_abbey_gardens_mono_shotgun_mic.wav.mp3 (124.00s)
# 🚫 Filtruji: 491634_Window_pats_and_slams.wav.mp3 (28.50s)
# 🚫 Filtruji: 740070_Daisy_Powerline_880_blank_shot_1.mp3 (3.89s)
# 🚫 Filtruji: 240653_BASKETBALL_WARMUPS_2A.wav.mp3 (99.79s)
# 🚫 Filtruji: 578192_gunfire_identify_weapon_ak47_shotgun_pistol_long_gun_3.mp3 (4.60s)
# 🚫 Filtruji: 57945_bbsingun.wav.mp3 (14.18s)
# 🚫 Filtruji: 24272_weirdplane.wav.mp3 (23.41s)
# 🚫 Filtruji: 660973_rack_1.ogg.mp3 (3.50s)
# 🚫 Filtruji: 435408_Shells_in_bag_-_Taking_gun_out_of_sleeve.wav.mp3 (12.84s)
# 🚫 Filtruji: 492771_Blowtorch_recorded_with_Rode_Shotgun_Microphone_post-processed_in_Reaper.wav.mp3 (5.11s)
# 🚫 Filtruji: 685391_Generic_Hand_Gun_Gun_Shot_With_Mag_Insert,_Cocking,_Firing,_Bullet_drops.mp3 (5.28s)
# 🚫 Filtruji: 617001_Wind_Turbine.wav.mp3 (778.97s)
# 🚫 Filtruji: 708200_Blowing_up_Balloon:_Slowly_blowing,_two_long_breaths._hollow_sound,_breaths_inbetween._Recorded_with_ZoomH6,_with_Rifle_Microphone,_EQ_used_to_cut_low_frequencies..mp3 (11.71s)
# 🚫 Filtruji: 249596_Electricity.wav.mp3 (12.79s)
# 🚫 Filtruji: 37902_20070722.ambiance.pinewood.passing.plane.flac.mp3 (609.70s)
# 🚫 Filtruji: 351428_Sniper_rifle_sound_effect.mp3.mp3 (3.02s)
# 🚫 Filtruji: 128275_Sharp_hit_2.aif.mp3 (0.17s)
# 🚫 Filtruji: 317659_Pistol_-_Reload,_cock,_shoot_sound_effects..mp3 (26.75s)
# 🚫 Filtruji: 212680_Firework_Explosions_Distance_2.mp3 (39.72s)
# 🚫 Filtruji: 520041_Grenade_Fire_Eplosion_07.wav.mp3 (3.90s)
# 🚫 Filtruji: 761500_Railgun_fire.mp3 (3.86s)
# 🚫 Filtruji: 562628_sound5transformation_reverb.wav.mp3 (6.53s)
# 🚫 Filtruji: 232867_357_Magnum_Ext_2_shots_Empty_Chamber_Clicks.wav.mp3 (11.91s)
# 🚫 Filtruji: 410552_Rifle_kaliber_6.5-55_compressed_the_spike_by_12_dB.wav.mp3 (5.02s)
# 🚫 Filtruji: 675669_S18-23_Rifle_shots_with_reverb.wav.mp3 (7.44s)
# 🚫 Filtruji: 448945_Toy_AK-74_Rifle_Full_Auto_Loop.mp3 (0.50s)
# 🚫 Filtruji: 77247_Mauser_3.08_load_and_shot.wav.mp3 (3.45s)
# 🚫 Filtruji: 190017_Nail_clippers_falling.wav.mp3 (12.50s)
# 🚫 Filtruji: 438567_G35-03-Shotgun_Blasts.wav.mp3 (51.70s)
# 🚫 Filtruji: 435411_Side_by_side_multiple_shooters.wav.mp3 (5.12s)
# 🚫 Filtruji: 406111_Bolt-Action_Cocking.wav.mp3 (9.39s)
# 🚫 Filtruji: 390616_toy_gun_trigger_lighter.mp3 (8.56s)
# 🚫 Filtruji: 611903_shotgun_forest_thunder_Albarracin_300821_David_Albanes_Bonillo_SONOTOMIA.wav.mp3 (43.92s)
# 🚫 Filtruji: 675601_S20-25_Machine_gun_with_battle_in_background.wav.mp3 (95.78s)
# 🚫 Filtruji: 734094_Explosion_Pine_Forest_200m.mp3 (6.95s)
# 🚫 Filtruji: 65695_playingraquetball.wav.mp3 (29.18s)
# 🚫 Filtruji: 326442_Battle,_war_zone_gun_fight.mp3 (40.15s)
# 🚫 Filtruji: 232954_shotgun_UTS-15_slugshot_with_pump_action.wav.mp3 (30.71s)
# 🚫 Filtruji: 76093_45_pistol_load_2_shots.wav.mp3 (5.22s)
# 🚫 Filtruji: 94693_Dryer_Ambiance.wav.mp3 (39.01s)
# 🚫 Filtruji: 159704_Bryco_Arms_Model_38_-_1_shot,_then_dryfire.mp3 (3.81s)
# 🚫 Filtruji: 729121_Alien_Weapon_Shotgun_.mp3 (4.64s)
# 🚫 Filtruji: 564641_Pistol_reload.mp3 (5.32s)
# 🚫 Filtruji: 327386_Opening_and_closing_wooden_drawer_OWI.wav.mp3 (12.00s)
# 🚫 Filtruji: 675009_Rifle_dropped_on_floor_3x.mp3 (3.73s)
# 🚫 Filtruji: 491631_Sword_put_in_and_out_of_sheath.wav.mp3 (39.00s)
# 🚫 Filtruji: 251960_Freeway_Traffic.mp3 (20.31s)
# 🚫 Filtruji: 177011_Artillery_Drone_Banana_Yellow.wav.mp3 (22.00s)
# 🚫 Filtruji: 564644_Pistol_dry_fire.mp3 (4.25s)
# 🚫 Filtruji: 162432_Rossi-Revolver_96kHz-24bit.wav.mp3 (28.29s)
# 🚫 Filtruji: 170827_Various_S&W_Model_39_handling_sounds.mp3 (76.61s)
# 🚫 Filtruji: 108438_Nerf_Gun.wav.mp3 (5.04s)
# 🚫 Filtruji: 675668_S06-03_Rifle_shots_with_reverb_and_noise.wav.mp3 (60.36s)
# 🚫 Filtruji: 274219_printer_close.wav.mp3 (374.74s)
# 🚫 Filtruji: 407515_Man_shushing.wav.mp3 (4.50s)
# 🚫 Filtruji: 769904_ShotgunPump.mp3 (21.68s)
# 🚫 Filtruji: 575804_Big_Laser_Beam.mp3 (6.21s)
# 🚫 Filtruji: 536636_Gunshot_03.sse.wav.mp3 (3.32s)
# 🚫 Filtruji: 222063_Flash_bang_in_war.mp3 (9.69s)
# 🚫 Filtruji: 580893_hit_explosion_2.wav.mp3 (1.80s)
# 🚫 Filtruji: 391312_Semi-automatic_Rifle.mp3 (6.44s)
# 🚫 Filtruji: 516747_Nerf_Disruptor_Shot.mp3 (4.35s)
# 🚫 Filtruji: 84430_shotgun_cocked_and_fired.wav.mp3 (3.41s)
# 🚫 Filtruji: 145475_Firearm_Reloading.mp3 (11.41s)
# 🚫 Filtruji: 267341_Bullet_hit.mp3 (0.75s)
# 🚫 Filtruji: 339999_Cage_Rattling.mp3 (14.00s)
# 🚫 Filtruji: 386003_gunshot-layered.wav.mp3 (10.41s)
# 🚫 Filtruji: 758939_Glock_sounds.mp3 (17.43s)
# 🚫 Filtruji: 663925_metralleta.wav.mp3 (4.49s)
# 🚫 Filtruji: 432606_Distant_Gunshot.mp3 (6.35s)
# 🚫 Filtruji: 516746_Nerf_Disruptor_Trigger.mp3 (3.37s)
# 🚫 Filtruji: 693856_KAC_LAMG.wav.mp3 (22.41s)
# 🚫 Filtruji: 384987_Browning_Hi_Power.mp3 (3.67s)
# 🚫 Filtruji: 491565_Movement_on_bed.wav.mp3 (35.50s)
# 🚫 Filtruji: 611898_Shotgun_natural_hole_ambience_filter_Albarracin_walk_290821_David_Albanes_Bonillo_SONOTOMIA.wav.mp3 (28.29s)
# 🚫 Filtruji: 655768_Wall_Tennis.mp3.mp3 (8.98s)
# 🚫 Filtruji: 396326_SemiAutoRifle2.mp3 (4.36s)
# 🚫 Filtruji: 127846_Slow-mo_gunshot.wav.mp3 (7.54s)
# 🚫 Filtruji: 708202_Sawing_into_plank_of_wood_using_hand_saw:_Fast_movement,_scraping_sounds,_hollow_sounding._Pauses_in_movement._Recorded_with_ZoomH6,_with_Rifle_Microphone..mp3 (18.56s)
# 🚫 Filtruji: 765976_Pistol_movements.mp3 (17.90s)
# 🚫 Filtruji: 319009_Shotgun-Far.mp3.mp3 (6.05s)
# 🚫 Filtruji: 148828_.22pistol_targetside.mp3.mp3 (4.10s)
# 🚫 Filtruji: 504175_Tsamp7_Te_Papa_Door_Slam.wav.mp3 (0.88s)
# 🚫 Filtruji: 473934_bubble_gun_bubble_noise.mp3 (3.87s)
# 🚫 Filtruji: 675643_S05-13_Classic_western_optical_gunfire;_good_variety.wav.mp3 (99.80s)
# 🚫 Filtruji: 39063_atmo.build.wav.mp3 (4.85s)
# 🚫 Filtruji: 712557_krinkov-aks74u-rifle_cocking_and_racking.mp3 (7.67s)
# 🚫 Filtruji: 675666_S18-25_Rifle_shots_battle.wav.mp3 (79.70s)
# 🚫 Filtruji: 626216_dog_eating_dry_food_3.wav.mp3 (5.19s)
# 🚫 Filtruji: 713017_GUNMisc_Rifle_Or_Automatic_Rifle.Single_Shots.Close.Designed_EM.mp3 (95.52s)
# 🚫 Filtruji: 325715_Faling_of_Empty_Shotgun_Shells.wav.mp3 (18.50s)
# 🚫 Filtruji: 423113_Guns_&_Explosions_Album_-_Heavy_Object_Impact_10.wav.mp3 (4.00s)
# 🚫 Filtruji: 366231_viib12klingonmusic.wav.mp3 (226.67s)
# 🚫 Filtruji: 653433_Mossberg_590_12_Gauge_Loading_Shells_Into_Tube.wav.mp3 (9.50s)
# 🚫 Filtruji: 203339_Three-volley_salute.wav.mp3 (5.94s)
# 🚫 Filtruji: 707537_Small_Garden_fork_(with_fly).wav.mp3 (7.45s)
# 🚫 Filtruji: 705494_LASRGun_Warp_Rifle_Energy_Blast_Funky_Audio_Sonic_Spices.mp3 (22.56s)
# 🚫 Filtruji: 315858_gunshot_ricochet.aiff.mp3 (5.54s)
# 🚫 Filtruji: 505206_M1GarandSafetyAppliedThenDisengaged.mp3.mp3 (11.07s)
# 🚫 Filtruji: 266379_bird_in_oostduinen_20.wav.mp3 (5.40s)
# 🚫 Filtruji: 481849_R17-26-Canvas_Bag.wav.mp3 (41.29s)
# 🚫 Filtruji: 764550_CZ_P09_Reload_and_Slide_Release.mp3 (4.50s)
# 🚫 Filtruji: 741062_Diablo_12g_pistol_6_inch,_open_and_close_breech_1.mp3 (5.64s)
# 🚫 Filtruji: 767312_GUNHndl_Revolver_Removal_from_Leather_Holster_HvD_OwSFX.mp3 (7.54s)
# 🚫 Filtruji: 246220_click_clack_Metal_Noise_.wav.mp3 (1.30s)
# 🚫 Filtruji: 795318_Revolver_Cylinder_Turn_-_Remington_1875.mp3 (7.23s)
# 🚫 Filtruji: 765478_Footsteps_on_Gravel.mp3 (8.84s)
# 🚫 Filtruji: 147038_Gun_Talk.mp3.mp3 (8.36s)
# 🚫 Filtruji: 558210_gun_I:_SMG_1.wav.mp3 (6.61s)
# 🚫 Filtruji: 33450_32cal_pistol.wav.mp3 (44.48s)
# 🚫 Filtruji: 65693_playingflagcracker.wav.mp3 (16.22s)
# 🚫 Filtruji: 440838_Energy_Rifle_Shot.wav.mp3 (7.59s)
# 🚫 Filtruji: 234616_WAR_MACHINEGUN_SHOOTING_003.wav.mp3 (4.74s)
# 🚫 Filtruji: 119166_Mag-loading.wav.mp3 (16.68s)
# 🚫 Filtruji: 223105_Gun_Shots_-_Pistols.mp3 (86.72s)
# 🚫 Filtruji: 486049_R12-18-Machine_Gun_Bursts.wav.mp3 (33.07s)
# 🚫 Filtruji: 408432_Dirt_scratch.wav.mp3 (6.50s)
# 🚫 Filtruji: 611905_shotgun_bug_flying_buzz_Albarracin_300821_David_Albanes_Bonillo_SONOTOMIA.wav.mp3 (8.75s)
# 🚫 Filtruji: 492786_Sails_in_the_wind_recorded_with_Rode_Shotgun_Microphone_post-processed_in_Reaper.wav.mp3 (6.59s)
# 🚫 Filtruji: 338045_Pistol_Walther_P-38_9mm_WW2_German__-_shoot_twice_in_the_forest.wav.mp3 (3.44s)
# 🚫 Filtruji: 707516_Drill_through_wood.wav.mp3 (6.70s)
# 🚫 Filtruji: 396327_SemiAutoRifle3.mp3 (4.36s)
# 🚫 Filtruji: 160355_Air_Defense_Artillery_Avenger_Training_.50cal_(tH4YBTw8vk8).flac.mp3 (6.28s)
# 🚫 Filtruji: 263766_11092014_torzym_closed_window.mp3.mp3 (170.85s)
# 🚫 Filtruji: 764601_Gunshots.mp3 (25.52s)
# 🚫 Filtruji: 407510_Little_Dog_Moaning.wav.mp3 (49.00s)
# 🚫 Filtruji: 767309_EQUIPTact_Leather_Revolver_Holster_Open_and_Close_HvD_OwSFX.mp3 (10.48s)
# 🚫 Filtruji: 675137_S19-18_Distant_pistol_gun_battle.wav.mp3 (32.73s)
# 🚫 Filtruji: 238347_Me_doing_The_Frog.flac.mp3 (83.95s)
# 🚫 Filtruji: 594481_Gunshots_.wav.mp3 (4.93s)
# 🚫 Filtruji: 441796_180081_Casings_Falling_02.WAV.mp3 (8.62s)
# 🚫 Filtruji: 125464_homemadeplatelong.wav.mp3 (3.26s)
# 🚫 Filtruji: 786111_TF_shockwave_inspired_laser_sound_02.mp3 (7.41s)
# 🚫 Filtruji: 169155_WEATHER-LIGHTNING,_CLOSE-Very_close_lightnin,_10-20_meters_away,_gunshot_like-0001.wav.mp3 (25.00s)
# 🚫 Filtruji: 681673_IMI_Galil_Assault_Rifle_Cocks_and_Dry_Fire.mp3.mp3 (24.91s)
# 🚫 Filtruji: 82459_50BMG.wav.mp3 (10.18s)
# 🚫 Filtruji: 516757_X-Shot_Chaos_Meteor_Magazine_Sounds.mp3 (17.41s)
# 🚫 Filtruji: 409798_Paintball_gun_being_loaded_and_released_sound.mp3 (6.17s)
# 🚫 Filtruji: 681693_Shotgun_Spas-12_Pump_Action;_Cock_and_Dry_Fire_with_Shells_Dropping.mp3.mp3 (29.79s)
# 🚫 Filtruji: 367346_Pistol_sliding_and_colliding.WAV.mp3 (41.88s)
# 🚫 Filtruji: 165429_military_war__.mp3.mp3 (90.02s)
# 🚫 Filtruji: 640721_Machine_Gun.wav.mp3 (11.08s)
# 🚫 Filtruji: 414827_Gun_Version_2_with_forward_bolt.mp3 (6.00s)
# 🚫 Filtruji: 170600_Cinematic_Rifle_Shot.mp3 (14.00s)
# 🚫 Filtruji: 25451_03_dogwalk_(new_2).wav.mp3 (7.92s)
# 🚫 Filtruji: 675123_S17-12_Barrage_with_shell_whines_and_heavy_machine_guns.wav.mp3 (37.65s)
# 🚫 Filtruji: 707784_Hockey_ball_hit_with_hockey_stick_1.mp3 (23.00s)
# 🚫 Filtruji: 708204_Hitting_Nail_into_Wall_with_Hammer:_Banging_sounds,_brick_wall,_room_with_reverb._Fast_and_slow_hammering._Recorded_with_ZoomH6,_with_Rifle_Microphone,_compressor_used_to_prevent_clipping..mp3 (12.19s)
# 🚫 Filtruji: 332934_Tykki,_laukaus_ja_kaiku___Big_gun,_cannon,_155_mm,_shot,_gunshot_2_x,_a_long,_hefty_echo_.mp3 (35.74s)
# 🚫 Filtruji: 249779_smgshoot2.wav.mp3 (21.47s)
# 🚫 Filtruji: 19514_22_rifle_02.wav.mp3 (9.77s)
# 🚫 Filtruji: 38300_20070722.pinar_0930am.flac.mp3 (120.81s)
# 🚫 Filtruji: 211439_laser_pistol_shots.aiff.mp3 (21.71s)
# 🚫 Filtruji: 171623_Rem870_Slide_Backward_1.mp3.mp3 (3.00s)
# 🚫 Filtruji: 245103_Small_Couch_Falling_Off_Balcony.wav.mp3 (5.05s)
# 🚫 Filtruji: 660971_rack_3.ogg.mp3 (3.60s)
# 🚫 Filtruji: 437243_Very_close_lightning_strike..mp3 (63.82s)
# 🚫 Filtruji: 478185_M41A_Pulse_rifle.wav.mp3 (15.40s)
# 🚫 Filtruji: 78776_Rifle-223_cal_(take_2).mp3 (4.34s)
# 🚫 Filtruji: 445579_Garden_rake_on_grass.wav.mp3 (7.70s)
# 🚫 Filtruji: 434716_Toy_Gun_3.mp3 (4.77s)
# 🚫 Filtruji: 378248_.32_Cal_Pistol_-_Cleaned_Up.mp3 (18.69s)
# 🚫 Filtruji: 431833_Sauer_404_four_shots_close_w:_extra_shooter.wav.mp3 (13.72s)
# 🚫 Filtruji: 655760_Golf_Drive.mp3.mp3 (152.16s)
# 🚫 Filtruji: 370308_distant_Hollywood-western_rifle-simulation.flac.mp3 (4.79s)
# 🚫 Filtruji: 794816_A_Gun_shot.mp3 (8.06s)
# 🚫 Filtruji: 802672_A_gun_salute_with_blank_cartridges_from_rifles,_revolvers_and_machine_guns_from_the_early_20th_century_during_a_historical_reenactment..mp3 (34.75s)
# 🚫 Filtruji: 127192_110801-unloading.wav.mp3 (1074.23s)
# 🚫 Filtruji: 231207_M4A1Reload02.wav.mp3 (6.80s)
# 🚫 Filtruji: 182818_Iraq_Arabic_Battle_Scene.flac.mp3 (36.32s)
# 🚫 Filtruji: 255215_Real_shotgun_(shot_&_reload).mp3 (25.43s)
# 🚫 Filtruji: 266380_bird_in_oostduinen_19.wav.mp3 (30.31s)
# 🚫 Filtruji: 675122_S17-11_Barrage_with_shell_whines_and_heavy_machine_guns.wav.mp3 (60.56s)
# 🚫 Filtruji: 435401_Single_shot_very_windy_conditions.wav.mp3 (3.88s)
# 🚫 Filtruji: 708198_Vinyl_Player_Crackle:_Needle_onto_vinyl_in_vinyl_player,_crackle_just_before_music_starts._Recorded_with_ZoomH6,_with_rifle_microphone_EQ_used_to_cut_away_the_low_ruble_of_the_vinyl_player_itself..mp3 (8.66s)
# 🚫 Filtruji: 435407_Distant_gun_shots_with_wind_noise.wav.mp3 (13.40s)
# 🚫 Filtruji: 255264_Kivääri,_kaikuvia_laukauksia_ulkona,_kooste___A_rifle_or_two,_echoing,_solid_shots,_exterior,_mix.mp3 (143.88s)
# 🚫 Filtruji: 404561_AssaultRifle2.wav.mp3 (3.50s)
# 🚫 Filtruji: 243734_Fireworks_#1.wav.mp3 (417.97s)
# 🚫 Filtruji: 513354_Racking_Shotgun.wav.mp3 (10.66s)
# 🚫 Filtruji: 542710_170339_Berno_Smit_Bolt_action_rifle_bullet_ejection.wav.mp3 (16.29s)
# 🚫 Filtruji: 147317_Gun_Shot_Close.wav.mp3 (4.68s)
# 🚫 Filtruji: 741060_Diablo_12g_pistol_6_inch,_cocking_back_slowly_3.mp3 (3.09s)
# 🚫 Filtruji: 719404_Shotgun_Skeet_Shooting.mp3 (3.50s)
# 🚫 Filtruji: 520963_Laser_Charge_And_Fire.mp3 (6.21s)
# 🚫 Filtruji: 611934_classic_film_gunshots.flac.mp3 (119.65s)
# 🚫 Filtruji: 435404_Shells_in_pockets_-_Rustling_around.wav.mp3 (4.68s)
# 🚫 Filtruji: 703342_S&W_M&P9_Shield:_one_round_fired_at_night_(no_processing).mp3 (11.80s)
# 🚫 Filtruji: 508746_Pump_Action_Shotgun_Reload.mp3 (19.90s)
# 🚫 Filtruji: 347874_countryside_atmosphere_with_one_shot.wav.mp3 (55.47s)
# 🚫 Filtruji: 707799_Wooden_frog_ornament_1.mp3 (20.50s)
# 🚫 Filtruji: 707778_Bees_buzzing_1.mp3 (301.73s)
# 🚫 Filtruji: 207970_Amb_Pati_Interior_Ciutat.wav.mp3 (92.08s)
# 🚫 Filtruji: 25039_20061105.gunshot.03.wav.mp3 (3.95s)
# 🚫 Filtruji: 320431_Duck_shooting.mp3 (122.64s)
# 🚫 Filtruji: 445107_Airsoft_Gun_cock.mp3 (13.51s)
# 🚫 Filtruji: 469547_Gun_safety_check_and_loading.mp3 (45.43s)
# 🚫 Filtruji: 438565_G35-01-Distant_Rifle_Shots.wav.mp3 (26.93s)
# 🚫 Filtruji: 232272_Idle_and_Rev_-_Engine.wav.mp3 (33.08s)
# 🚫 Filtruji: 459638_handle_3.wav.mp3 (3.56s)
# 🚫 Filtruji: 698737_Baby_Desert_Eagle_III_9mm_Trigger_Reset_(1).ogg.mp3 (0.10s)
# 🚫 Filtruji: 460857_GUNMech_M1_GARAND_SLIDE_PULL_BACK_MP.wav.mp3 (6.21s)
# 🚫 Filtruji: 779237_Gunshots_machine_gun_with_silencer_in_a_shooting_range.mp3 (14.50s)
# 🚫 Filtruji: 407503_Electrical_sander_turning_on_and_off.wav.mp3 (19.00s)
# 🚫 Filtruji: 327387_Starting_a_vacuum_cleaner_OWI.wav.mp3 (11.00s)
# 🚫 Filtruji: 790979_GUNShotg_Winchester_1300_Load_Push_01_KVV_AUDIO_FREE.mp3 (9.50s)
# 🚫 Filtruji: 404560_AssaultRifle3.wav.mp3 (3.50s)
# 🚫 Filtruji: 653537_Riffle_shot_far_2.wav.mp3 (15.89s)
# 🚫 Filtruji: 435757_Apartment_street_2_WAV.mp3 (194.00s)
# 🚫 Filtruji: 244768_Fireworks-Finale.flac.mp3 (63.98s)
# 🚫 Filtruji: 332479_20160102_shot.wav.mp3 (10.00s)
# 🚫 Filtruji: 784310_mechanical_stapler_sounds_01062025.mp3 (37.64s)
# 🚫 Filtruji: 741070_Diablo_12g_pistol_6_inch,_open_breech,_close_breech_and_cock_back_2.mp3 (6.43s)
# 🚫 Filtruji: 528044_Scary_Ambient_Bass.mp3 (29.44s)
# 🚫 Filtruji: 57944_bbgunperspective.wav.mp3 (123.93s)
# 🚫 Filtruji: 790334_xdrone_02.mp3 (4.32s)
# 🚫 Filtruji: 65752_00762_gunshot_2.wav.mp3 (4.10s)
# 🚫 Filtruji: 677282_vibrations_wet.wav.mp3 (7.04s)
# 🚫 Filtruji: 76094_45-2_shots_distant.wav.mp3 (3.80s)
# 🚫 Filtruji: 235678_gunshot.wav.mp3 (6.52s)
# 🚫 Filtruji: 150305_War_sounds.mp3 (15.23s)
# 🚫 Filtruji: 326042_m4_rifle_reload.wav.mp3 (8.90s)
# 🚫 Filtruji: 777293_custom_tiger_claw_ice_laser_sound_12182024.mp3 (3.17s)
# 🚫 Filtruji: 384717_Distant_Gunshot_1.wav.mp3 (3.48s)
# 🚫 Filtruji: 675678_S20-35_Pistol_shots;_ping;_silencer?.wav.mp3 (4.25s)
# 🚫 Filtruji: 346904_Revolver_calibre_38_-_vários_disparos_01.mp3 (3.69s)
# 🚫 Filtruji: 174642_Gun_Cleaning.mp3 (47.35s)
# 🚫 Filtruji: 699773_P38_Dry_Fire.ogg.mp3 (0.07s)
# 🚫 Filtruji: 241084_yellowhammer-ducks-pocklington__canal-18jun2014.mp3 (78.00s)
# 🚫 Filtruji: 689396_M1911_Pistol_.45_-_KWC__M1911A1_Airsoft_Pistol_Foley.mp3 (129.79s)
# 🚫 Filtruji: 245104_Large_Couch_Falling_Off_Balcony.wav.mp3 (6.88s)
# 🚫 Filtruji: 37238_Gun-Shot_Gun(one_shot).wav.mp3 (4.50s)
# 🚫 Filtruji: 441807_180081_Rilfe_Suppressor_01.WAV.mp3 (15.82s)
# 🚫 Filtruji: 233044_UTS-15_Shotgun_with_pump_action_4takes.wav.mp3 (6.62s)
# 🚫 Filtruji: 681497_Dragunov_SVD_Rifle_Mechan;_Empty_Mag_Inserted_Into_And_Pulled_Out.mp3 (30.60s)
# 🚫 Filtruji: 407507_Foot_steps_on_cement_in_squeeky_boots.wav.mp3 (11.00s)
# 🚫 Filtruji: 241730_Fairfield_City_Sounds_#2.wav.mp3 (240.02s)
# 🚫 Filtruji: 470782_epic_gun_rifle.flac.mp3 (5.42s)
# 🚫 Filtruji: 169576_CricketEarlyFallMorningSep212012.wav.mp3 (156.80s)
# 🚫 Filtruji: 685719_Pragersko_-_Shooting_and_Birds.wav.mp3 (68.16s)
# 🚫 Filtruji: 377551_AR_Reload.wav.mp3 (3.74s)
# 🚫 Filtruji: 388197_Slam_&_Fire.wav.mp3 (3.00s)
# 🚫 Filtruji: 263758_08092014_Torzym_Lake_Ilno.mp3.mp3 (82.59s)
# 🚫 Filtruji: 548008_Rifle_Gunshot_Tail.mp3 (8.50s)
# 🚫 Filtruji: 514887_12_Gauge_Shell_3.mp3 (4.13s)
# 🚫 Filtruji: 661435_Defensible_Twister.mp3 (433.00s)
# 🚫 Filtruji: 707789_Pig_sty_1.mp3 (240.83s)
# 🚫 Filtruji: 486072_R22-09-Big_Urban_Gun_Battle.wav.mp3 (40.78s)
# 🚫 Filtruji: 188967_regenopdak.wav.mp3 (240.09s)
# 🚫 Filtruji: 255267_Haulikko,_kaikuvia_laukauksia_ulkona___A_shotgun,_echoing_single_shots,_exterior.mp3 (34.60s)
# 🚫 Filtruji: 267895_Mosin_Nagant_Bolt_(fast).wav.mp3 (4.30s)
# 🚫 Filtruji: 638908_Magazine_sound_for_free.mp3 (4.67s)
# 🚫 Filtruji: 640700_distant_firework_boom_2.wav.mp3 (12.12s)
# 🚫 Filtruji: 242087_Door_Open-Door_Close_#1.wav.mp3 (61.97s)
# 🚫 Filtruji: 765491_Rustling_Bush_Leaves.mp3 (9.61s)
# 🚫 Filtruji: 243401_Train_Startion_Ambience.wav.mp3 (139.87s)
# 🚫 Filtruji: 576966_Theatre_gunshot_studio_theatre_KOT_2.flac.mp3 (7.22s)
# 🚫 Filtruji: 516976_machinegun.wav.mp3 (20.66s)
# 🚫 Filtruji: 232749_Semi-Automatic_Handgun_Ext.wav.mp3 (9.80s)
# 🚫 Filtruji: 445554_Toilet_brush_scrubbing_bowl,bathroom.wav.mp3 (13.71s)
# 🚫 Filtruji: 508747_Bolt_Action_Rifle_Reload.mp3 (25.73s)
# 🚫 Filtruji: 771044_DR0000_0601_sucking_gun_barrel.mp3 (19.85s)
# 🚫 Filtruji: 507705_Hit_1_8_Bit.wav.mp3 (0.55s)
# 🚫 Filtruji: 327520_Turning_pages_in_a_book_OWI.wav.mp3 (12.32s)
# 🚫 Filtruji: 438582_G35-17-Rifle_Cracks.wav.mp3 (14.12s)
# 🚫 Filtruji: 595494_OWI_Gun_shot.wav.mp3 (3.50s)
# 🚫 Filtruji: 89976_1AT05_2.WAV.mp3 (22.01s)
# 🚫 Filtruji: 802085_tf_one_inspired_megatron_transformation_collection_sounds_04252025.mp3 (6.65s)
# 🚫 Filtruji: 677396_Shotgun_range.mp3 (185.22s)
# 🚫 Filtruji: 15350_PLASMA_RIFLE_ROUND.wav.mp3 (3.31s)
# 🚫 Filtruji: 479353_Laser_Effect_Contact_Mic.mp3 (76.13s)
# 🚫 Filtruji: 608388_Last_Known_Recording.Wav.mp3 (58.44s)
# 🚫 Filtruji: 213098_Synth_Bombs_with_Synth_Machine_Guns.mp3 (22.07s)
# 🚫 Filtruji: 362358_Revolveri,_tyhjä,_laukaus___Empty_gun,_revolver,_shots,_cocking,_striker,_interior.mp3 (34.18s)
# 🚫 Filtruji: 93978_Spin_down_(beefier).wav.mp3 (38.04s)
# 🚫 Filtruji: 713217_Reloading_Shotgun.mp3 (15.71s)
# ...
# 🚫 Filtruji: 392374_toyGun.wav.mp3 (17.53s)
# 🚫 Filtruji: 741068_Diablo_12g_pistol_6_inch,_open_and_close_breech_6.mp3 (4.38s)
# 🚫 Filtruji: 118132_fly.wav.mp3 (34.09s)
# 🚫 Filtruji: 651786_AR-15_-_bolt_rack_in_a_large_room.mp3 (3.35s)
# 🚫 Filtruji: 417687_LightMachineGun2.wav.mp3 (43.20s)
# 🚫 Filtruji: 146421_Frozen_Lake_Ice_and_Water_Sounds_(+12.0dB)_Omni_Part_1.wav.mp3 (59.60s)
# 🚫 Filtruji: 682016_H&K_416_Assault_Rifle_Cocks_And_Dry_Fires_01.mp3 (25.46s)
# 🚫 Filtruji: 427505_S&W_M&P®9_M2.0™_handling_(actual:_room).mp3 (170.02s)
# 🚫 Filtruji: 544675_Shotgun_03.wav.mp3 (7.83s)
# 🚫 Filtruji: 476283_miscLoop.wav.mp3 (29.15s)
# 🚫 Filtruji: 673317_Loading_Shotgun.wav.mp3 (10.34s)
# 🚫 Filtruji: 30749_m240.wav.mp3 (12.76s)
# 🚫 Filtruji: 423111_Guns_&_Explosions_Album_-_Explosion_2.wav.mp3 (8.00s)
# 🚫 Filtruji: 2882_sonic_train_sample4.wav.mp3 (47.57s)
# 🚫 Filtruji: 523589_RamonaPark.wav.mp3 (7.90s)
# 🚫 Filtruji: 246273_Glass_Crunching_#1.wav.mp3 (25.23s)
# 🚫 Filtruji: 572361_180521_Fireworks,_urban_residential,_like_gunshots,_roof_ms.flac.mp3 (267.38s)
# 🚫 Filtruji: 395789_Darkscape_1911_A1.mp3 (3.13s)
# 🚫 Filtruji: 65892_clicks_02.wav.mp3 (13.43s)
# 🚫 Filtruji: 194706_bubbling-water-gun.wav.mp3 (71.71s)
# 🚫 Filtruji: 619041_Shot_Gun_-_12_Gauge-_Fire_Four_Shots_Quickly.mp3 (3.15s)
# 🚫 Filtruji: 166076_Gun_Battle_Long.wav.mp3 (20.16s)
# 🚫 Filtruji: 150500_Firearm_Reloading_2.mp3 (4.41s)
# 🚫 Filtruji: 707528_Sandpaper_on_wood.wav.mp3 (6.53s)
# 🚫 Filtruji: 212968_Drilling_Fast.mp3 (86.40s)
# 🚫 Filtruji: 639162_NL_AIRSOFT_GLOCK_17_BB_HANDLING_01.wav.mp3 (3.23s)
# 🚫 Filtruji: 675667_S19-01_Rifle_shots_with_good_reverb.wav.mp3 (24.63s)
# 🚫 Filtruji: 407545_Vape_Firing_Coils.mp3 (5.17s)
# 🚫 Filtruji: 410291_Step_gun.mp3 (12.36s)
# 🚫 Filtruji: 136399_Rifle_Gun_Shot_AK47._close_recording_in_a_shooting_range..mp3 (32.57s)
# 🚫 Filtruji: 763221_Airsoft_Pistol.mp3 (117.00s)
# 🚫 Filtruji: 90756_gobroeffekt.wav.mp3 (9.50s)
# 🚫 Filtruji: 245166_Toilet_Bowl_Breaking.wav.mp3 (3.80s)
# 🚫 Filtruji: 171629_Rem870_Slide_Forward_2.mp3.mp3 (3.00s)
# 🚫 Filtruji: 160880_BFG_Laser.mp3 (4.94s)
# 🚫 Filtruji: 491077_Metal_nail_falling.mp3 (1.36s)
# 🚫 Filtruji: 242594_Koeien,_R4_en_riet_Lichterveldestraat.wav.mp3 (98.00s)
# 🚫 Filtruji: 507489_archi_gunshot_scifi_09.flac.mp3 (6.50s)
# 🚫 Filtruji: 38299_20070722.pinar_0915am.flac.mp3 (229.58s)
# 🚫 Filtruji: 732127_Epic_Shotgun_Blast,_Reverb,_80s_Style.mp3 (7.08s)
# 🚫 Filtruji: 543710_Paper_Tear.wav.mp3 (16.00s)
# 🚫 Filtruji: 212681_Firework_Explosions_Distance_3.mp3 (36.16s)
# 🚫 Filtruji: 39065_battlefield.1.wav.mp3 (4.15s)
# 🚫 Filtruji: 681694_Shotgun_Spas-12_Pump_Action;_Cock_and_Dry_Fire_with_Speeds.mp3.mp3 (67.17s)
# 🚫 Filtruji: 241739_Grass-Boot_Footsteps_SFX_#1.wav.mp3 (85.92s)
# 🚫 Filtruji: 107806_metallicclick.wav.mp3 (0.14s)
# 🚫 Filtruji: 39069_explosion.2.wav.mp3 (3.69s)
# 🚫 Filtruji: 85571_Ext-amb_empty-open-field_distant-gunshot.aif.mp3 (26.41s)
# 🚫 Filtruji: 401925_Konepistooli_laukauksia_ja_sarjoja___Sub-machine_gun_shots_and_sustained_fire.mp3 (266.19s)
# 🚫 Filtruji: 57943_aluminum.wav.mp3 (34.64s)
# 🚫 Filtruji: 765359_nerfed_shotgun_pumping.mp3 (3.17s)
# 🚫 Filtruji: 319400_22multpl2.wav.mp3 (9.00s)
# 🚫 Filtruji: 675664_S20-38_Rifle_fire_at_the_receiving_end.wav.mp3 (12.65s)
# 🚫 Filtruji: 516753_Nerf_Tristrike_Shot_&_Reload.mp3 (10.78s)
# 🚫 Filtruji: 266916_Gun_shot_bullet_hit.mp3 (1.19s)
# 🚫 Filtruji: 675589_S20-22_50_cal_machine_gun_with_ricochets.wav.mp3 (17.43s)
# 🚫 Filtruji: 167364_Stream_2.wav.mp3 (76.37s)
# 🚫 Filtruji: 677278_vibrations_plastic.wav.mp3 (9.05s)
# 🚫 Filtruji: 766089_Cocking_AK_Rifle.mp3 (7.86s)
# 🚫 Filtruji: 445238_Firework_1.mp3 (17.00s)
# 🚫 Filtruji: 741111_Shotguns_racking_and_handling_sounds_part2.mp3 (21.66s)
# 🚫 Filtruji: 327126_Aerosol_Can_Spray_OWI.wav.mp3 (11.00s)
# 🚫 Filtruji: 741072_Diablo_12g_pistol_6_inch,_open_breech,_close_breech_quickly_1.mp3 (3.92s)
# 🚫 Filtruji: 407524_Sanding_wood.wav.mp3 (62.00s)
# 🚫 Filtruji: 676588_Colt_SMG_-_Firing,_Handling.mp3 (16.96s)
# 🚫 Filtruji: 767332_Custom_Transformers_prime_weapon_transformation_retracting_sound_1112024.mp3 (4.20s)
# 🚫 Filtruji: 495785_Noise_dist_shot_(2lrs,Eq,Ovrdr,filt)2.wav.mp3 (4.55s)
# 🚫 Filtruji: 233323_50_BMG_AM.mp3.mp3 (3.00s)
# 🚫 Filtruji: 244769_Fireworks-Crowd.flac.mp3 (43.17s)
# 🚫 Filtruji: 445701_Airsoft_Rifle.wav.mp3 (16.50s)
# 🚫 Filtruji: 260155_Short_Laser_Shots.mp3 (6.65s)
# 🚫 Filtruji: 708191_Farm_Ambience_(Irene_Farm):_Nature_sounds,_people_chatting_in_the_distance,_rooster_in_background,_dog_barking._Recorded_with_ZoomH6_in_stereo,_with_rifle_microphone..mp3 (168.44s)
# 🚫 Filtruji: 111853_Remix_of_111676__Dredile__revolvercock1_cleaner_(before-after).wav.mp3 (4.72s)
# 🚫 Filtruji: 735122_20240510_-_02_-_Mono_-_AT875R_-_Shooting_range_Velenik_-_The_police_practice_shooting.mp3 (252.53s)
# 🚫 Filtruji: 508744_Revolver_Reload.mp3 (25.14s)
# 🚫 Filtruji: 626930_Jatimatic_-_Jali_Timari.mp3.mp3 (3.66s)
# 🚫 Filtruji: 253434_Distant_Dogs,_Rooster,_Cat_Scratching.wav.mp3 (106.73s)
# 🚫 Filtruji: 655728_Airsoft_AR_Shooting.mp3.mp3 (15.24s)
# 🚫 Filtruji: 101962_Machine_gun.wav.mp3 (11.03s)
# 🚫 Filtruji: 629180_Gaj_-_shooting_range.wav.mp3 (246.36s)
# 🚫 Filtruji: 611908_shotgun_forest_water_Albarracin_300821_David_Albanes_Bonillo_SONOTOMIA.wav.mp3 (13.03s)
# 🚫 Filtruji: 733558_Picking_up_and_rifling_through_a_purse_handbag.mp3 (113.70s)
# 🚫 Filtruji: 246272_Canoga_Park_Traffic_#1.wav.mp3 (44.76s)
# 🚫 Filtruji: 769182_design_rhythjmic_bubble_machine_gun_spell_rapid_attack.mp3 (31.82s)
# 🚫 Filtruji: 330347_Revelation_Sweep.mp3 (5.01s)
# 🚫 Filtruji: 460553_fountain_3_abbey_gardens_mono_shotgun_mic.wav.mp3 (64.75s)
# 🚫 Filtruji: 155001_pistol_pew.mp3 (8.31s)
# 🚫 Filtruji: 233971_Makarov's_gun_dry_shot.mp3 (95.39s)
# 🚫 Filtruji: 261085_room-tone_wet_outdoors150113_0506.wav.mp3 (216.70s)
# 🚫 Filtruji: 207963_Dibuixant_a_llapis.wav.mp3 (14.04s)
# 🚫 Filtruji: 807662_07_-_Weaponry_-_T-25_Energy_Pistol_A.mp3 (4.00s)
# 🚫 Filtruji: 156007_M16_01.wav.mp3 (41.84s)
# 🚫 Filtruji: 507636_Similar_to_Metal_(stage_1)_80bpm_-_variation_4.mp3 (12.00s)
# 🚫 Filtruji: 76885_Marlin.wav.mp3 (16.44s)
# 🚫 Filtruji: 516749_Nerf_Roughcut_Trigger.mp3 (6.62s)
# 🚫 Filtruji: 445550_Saw_cutting_wood_fast_wav.mp3 (10.48s)
# 🚫 Filtruji: 159702_Bryco_Arms_Model_38_-_7_shots_alt.mp3 (6.16s)
# 🚫 Filtruji: 486079_R30-21-Pistol_or_Rifle_Single_Shots.wav.mp3 (15.96s)
# 🚫 Filtruji: 677284_vibrations_leather.wav.mp3 (18.00s)
# 🚫 Filtruji: 611899_Shotgun_cars_voices_lookout_point_Albarracin_walk_290821_David_Albanes_Bonillo_SONOTOMIA.wav.mp3 (78.84s)
# 🚫 Filtruji: 65531_avio.mp3.mp3 (28.58s)
# 🚫 Filtruji: 445110_Airsoft_Bullet_Impact.mp3 (10.12s)
# 🚫 Filtruji: 241729_Fairfield_City_Sounds_#3.wav.mp3 (604.30s)
# 🚫 Filtruji: 543483_200088_RossJuterbock_Spring_Action_Air_Rifle_Reload.wav.mp3 (4.00s)
# 🚫 Filtruji: 351226_shotgun_rack.wav.mp3 (3.48s)
# 🚫 Filtruji: 655788_Taser.mp3.mp3 (6.00s)
# 🚫 Filtruji: 492780_Getting_up_from_chair_recorded_with_Rode_Shotgun_Microphone_post-processed_in_Reaper.wav.mp3 (6.21s)
# 🚫 Filtruji: 681509_Desert_Eagle_50_Cal._Action_Express_Mark_Vii_Semi_Automatic_Pistol_Cocks_And_Dry_Fires_Various.mp3 (32.46s)
# 🚫 Filtruji: 266387_birds_in_oostduinen_11_wild_duck.wav.mp3 (160.00s)
# 🚫 Filtruji: 702225_FN_SCAR-H.mp3 (3.03s)
# 🚫 Filtruji: 741115_Winchester_M1897_Trench_Gun_reloading_sounds.mp3 (45.99s)
# 🚫 Filtruji: 681676_Grenade_Launcher_M203_M16_Assault_Rifle_Opening_And_Closing_The_Chamber.mp3.mp3 (24.52s)
# 🚫 Filtruji: 645844_Smoke_Machine_Blast_Long.wav.mp3 (5.00s)
# 🚫 Filtruji: 121766_Glock_17_Reload.wav.mp3 (6.58s)
# 🚫 Filtruji: 249778_handgun.wav.mp3 (14.69s)
# 🚫 Filtruji: 242854_Laser_Shot.mp3.mp3 (3.52s)
# 🚫 Filtruji: 680659_Various_Pistol_Sounds.mp3 (51.50s)
# 🚫 Filtruji: 400501_HD_Bombing_Flyby.mp3 (19.32s)
# 🚫 Filtruji: 508246_M1_30_Carbine_Being_Loaded.wav.mp3 (12.46s)
# 🚫 Filtruji: 435393_Several_shots_very_windy_conditions.wav.mp3 (10.64s)
# 🚫 Filtruji: 712558_krinkov-aks74u-rifle_switch.mp3 (10.23s)
# 🚫 Filtruji: 59977_Battlefield.wav.mp3 (11.34s)
# 🚫 Filtruji: 438576_G35-11-Shotgun_with_Reload.wav.mp3 (84.97s)
# 🚫 Filtruji: 241734_San_Francisco_City_Sounds_#2.wav.mp3 (329.10s)
# 🚫 Filtruji: 516968_gunshot.wav.mp3 (20.66s)
# 🚫 Filtruji: 327382_Man_Brushing_his_Teeth_OWI.wav.mp3 (11.00s)
# 🚫 Filtruji: 611396_loudinsdrumstrial.wav.mp3 (2.00s)
# 🚫 Filtruji: 528042_Horror_Synth_2.mp3 (10.09s)
# 🚫 Filtruji: 351777_Sniper_Rifle_M24_SFX.mp3.mp3 (3.96s)
# 🚫 Filtruji: 52202_Single_Barreled_Shotgun_Loading.wav.mp3 (15.41s)
# 🚫 Filtruji: 82019_Distant_Hunt_With_Shots.wav.mp3 (185.21s)
# 🚫 Filtruji: 491857_garage_sliding_doors_open_and_closing.wav.mp3 (13.00s)
# 🚫 Filtruji: 366776_AirRifleGunshot.wav.mp3 (15.50s)
# 🚫 Filtruji: 507487_archi_gunshot_scifi_06.flac.mp3 (7.29s)
# 🚫 Filtruji: 57949_cleanupthencan1.wav.mp3 (86.75s)
# 🚫 Filtruji: 675133_S17-19_Bombardment_with_light_battle_background;_then_close_constant_machine_gun.wav.mp3 (108.85s)
# 🚫 Filtruji: 514047_blaster_shot_1_1(Sytrus,rsmpl,multiprcsng)series.wav.mp3 (5.31s)
# 🚫 Filtruji: 493899_FX_Drawer_Open_Rustling_01.wav.mp3 (22.00s)
# 🚫 Filtruji: 200184_Pedal_Hi-hat_Hit_-_PHi-hat-NTG-1-1-T.flac.mp3 (4.94s)
# 🚫 Filtruji: 209924_12_gauge_pump.mp3 (4.84s)
# 🚫 Filtruji: 682015_Dragunov_SVD_Rifle_Reload_02.mp3.mp3 (6.02s)
# 🚫 Filtruji: 338941_police_dog_practice_160305_0861.ogg.mp3 (2564.00s)
# 🚫 Filtruji: 708246_acrylic_fake_nails_tapping_on_various_materials.mp3 (35.00s)
# 🚫 Filtruji: 402093_diamonds_in_a_bag.wav.mp3 (37.34s)
# 🚫 Filtruji: 693731_Sci_Fi_Designed_Gunshot_2.mp3 (19.50s)
# 🚫 Filtruji: 762704_Custom_Heavy_intense_punches_or_kicking_sounds_10242024.mp3 (53.92s)
# 🚫 Filtruji: 730594_DSGNSynth_ZAP_LARGE-Data_Rifle_BSL_LqdScifi.mp3 (24.00s)
# 🚫 Filtruji: 329552_FXLM_neon_lights_tv_studio_far_switched_on_vari_ssg_denoise.wav.mp3 (66.70s)
# 🚫 Filtruji: 329553_FXLM_lightswitch_tv_studio_close_on_off.wav.mp3 (9.36s)
# 🚫 Filtruji: 586915_Powerful_blaster_shot_x2.With_tail_and_explosion_1-2(8lrs).wav.mp3 (13.33s)
# 🚫 Filtruji: 241736_San_Francisco_City_Sounds_#6.wav.mp3 (303.11s)
# 🚫 Filtruji: 209910_English_Winter_Stream.mp3 (1992.34s)
# 🚫 Filtruji: 317074_Storm_and_thunder.mp3 (244.32s)
# 🚫 Filtruji: 142894_mossberg_.12_gauge_pump.aif.mp3 (17.38s)
# 🚫 Filtruji: 434718_Toy_Gun_1.mp3 (6.46s)
# 🚫 Filtruji: 241731_Fairfield_City_Sounds_#1.wav.mp3 (311.87s)
# 🚫 Filtruji: 611883_shotgun_moving_stones_in_stone_river_Sierra_Albarracin_010921_David_Albanes_Bonillo_SONOTOMIA.wav.mp3 (15.80s)
# 🚫 Filtruji: 46655_carbine_single.wav.mp3 (3.34s)
# 🚫 Filtruji: 64389_Kinfe_Drone.wav.mp3 (24.40s)
# 🚫 Filtruji: 432596_daisy63_lawnmower_close.wav.mp3 (400.96s)
# 🚫 Filtruji: 202725_Rocket_Launcher.wav.mp3 (8.36s)
# 🚫 Filtruji: 513817_MachineGunJordan.mp3 (8.12s)
# 🚫 Filtruji: 762860_GUN_asmr_3_glock_slide_lock_back_and_release_10312024.mp3 (34.24s)
# 🚫 Filtruji: 445784_Shotgun_cocking.WAV.mp3 (14.35s)
# 🚫 Filtruji: 327501_Rubbing_on_guitar_strings_OWI.wav.mp3 (23.52s)
# 🚫 Filtruji: 440143_SciFi_Gun_-_Laser_Automatic_Fast.mp3 (4.00s)
# 🚫 Filtruji: 491637_Drawing_book_pages_flip.wav.mp3 (50.00s)
# 🚫 Filtruji: 411567_Centerfire_Rifle_Gun_Shot_01.wav.mp3 (3.18s)
# 🚫 Filtruji: 517058_scifi_sniper_rifle.wav.mp3 (3.54s)
# 🚫 Filtruji: 434721_Toy_Gun_6.mp3 (3.19s)
# 🚫 Filtruji: 57950_lowvelocitybottles.wav.mp3 (100.41s)
# 🚫 Filtruji: 234618_WAR_MACHINEGUN_SHOOTING_001.wav.mp3 (4.17s)
# 🚫 Filtruji: 639182_NL_AIRSOFT_GLOCK_17_INDOOR_SHOT_WET_HIT_TARGET_02.wav.mp3 (1.28s)
# 🚫 Filtruji: 320135_Pistooli,_laukaus_sisällä___Pistol,_Mauser_7.65,_shot,_two_gunshots,_interior.mp3 (8.70s)
# 🚫 Filtruji: 182790_Sniper_Fire.flac.mp3 (6.10s)
# 🚫 Filtruji: 242510_Rumbling_Rollup_Door.wav.mp3 (71.68s)
# 🚫 Filtruji: 674748_Ruger_10_22_rifle_being_reloaded_while_empty._Full_sequence.mp3 (6.02s)
# 🚫 Filtruji: 523579_machine_gun.mp3.mp3 (7.70s)
# 🚫 Filtruji: 266386_bird_oostduinen_9.wav.mp3 (28.00s)
# 🚫 Filtruji: 681491_AK47_Assault_Rifle_Cocking_Speed.mp3 (25.33s)
# 🚫 Filtruji: 104184_three_shots_and_reload.wav.mp3 (7.63s)
# 🚫 Filtruji: 242597_Mussen_en_R4_Desteldonkdorp-Lichterveldestraat.wav.mp3 (175.45s)
# 🚫 Filtruji: 675653_S19-12_30-30_rifle_shots.wav.mp3 (9.11s)
# 🚫 Filtruji: 148830_.223_gunside.mp3.mp3 (4.08s)
# 🚫 Filtruji: 327511_Turning_off_a_vacuum_cleaner_OWI.wav.mp3 (11.48s)
# 🚫 Filtruji: 673320_Shotgun_Pump.wav.mp3 (3.63s)
# 🚫 Filtruji: 486075_R28-36-Handling_and_Rattling_Rifle.wav.mp3 (26.00s)
# 🚫 Filtruji: 705391_Machine_Gun.mp3 (4.60s)
# 🚫 Filtruji: 745278_Killing_sound_for_movies.mp3 (5.03s)
# 🚫 Filtruji: 681510_Desert_Eagle_50_Cal._Action_Express_Mark_Vii_Semi_Automatic_Pistol_Mechan;_Empty_Mag_Inserted_Into_And_Pulled_Out.mp3 (38.13s)
# 🚫 Filtruji: 242009_Girl_Scream_#1.wav.mp3 (15.29s)
# 🚫 Filtruji: 707541_Broom_on_grass.wav.mp3 (4.51s)
# 🚫 Filtruji: 481847_R17-20-Rifling_Through_a_Desk.wav.mp3 (38.30s)
# 🚫 Filtruji: 675654_S20-08_Active_rifle_fire.wav.mp3 (28.61s)
# 🚫 Filtruji: 708193_Pouring_Beads_into_Glass_Bowl:_Beads_dropping_into_a_glass_bowl,_light_sound,_magical._Recorded_with_ZoomH6,_with_rifle_microphone..mp3 (6.76s)
# 🚫 Filtruji: 620929_empty_shotgun_shells_casings_hitting_ground_bouncing.mp3 (2.27s)
# 🚫 Filtruji: 677277_vibrations_bassy.wav.mp3 (7.70s)
# 🚫 Filtruji: 408430_Cupboard_shift,_drawer_wood.wav.mp3 (12.15s)
# 🚫 Filtruji: 360748_gunshot_and_reverse.wav.mp3 (3.40s)
# 🚫 Filtruji: 169170_50CaliberOnePigRoast2012.mp3.mp3 (38.19s)
# 🚫 Filtruji: 515197_rifle,_223,_caliber_rifle,_two_rapid_shots.mp3 (4.20s)
# 🚫 Filtruji: 377789_gun_9mm_15m_in_front_m10.wav.mp3 (31.57s)
# 🚫 Filtruji: 266377_bird_in_oostduinen_16.wav.mp3 (28.55s)
# 🚫 Filtruji: 693735_Sci_Fi_Designed_Gunshot.mp3 (19.50s)
# 🚫 Filtruji: 750269_Machine_Gun_Fire.mp3 (47.55s)
# 🚫 Filtruji: 367343_Pistol_Cocking_sounds.WAV.mp3 (30.03s)
# 🚫 Filtruji: 205588_Gunfire.mp3 (73.69s)
# 🚫 Filtruji: 578194_gunfire_help_identify_weapon_ak47_shotgun_pistol_long_gun_5.mp3 (3.18s)
# 🚫 Filtruji: 317358_Laser.wav.mp3 (3.15s)
# 🚫 Filtruji: 338240_Battle_in_the_forest_-_Mosin_Vs_Mauser_WW2.wav.mp3 (13.28s)
# 🚫 Filtruji: 611909_shotgun_forest_thunder_insects_birds_Albarracin_300821_David_Albanes_Bonillo_SONOTOMIA.wav.mp3 (77.93s)
# 🚫 Filtruji: 443912_Noir..mp3 (60.05s)
# 🚫 Filtruji: 660770_Hit_Impact.mp3 (0.45s)
# 🚫 Filtruji: 145087_AMB-Freezer-Indside-Idle-01.wav.mp3 (11.98s)
# 🚫 Filtruji: 120513_Gun_reload_ambient_1.wav.mp3 (3.16s)
# 🚫 Filtruji: 148831_.223_gunside_automatic.mp3.mp3 (4.44s)
# 🚫 Filtruji: 564313_Thermal_Sniper_shot_4.wav.mp3 (3.26s)
# 🚫 Filtruji: 26141_gunshots.wav.mp3 (4.87s)
# 🚫 Filtruji: 543695_Ambience_with_shots.wav.mp3 (132.00s)
# 🚫 Filtruji: 427594_22_magnum_pistol_shot.mp3 (3.13s)
# 🚫 Filtruji: 244766_Fireworks-Street2.flac.mp3 (51.55s)
# 🚫 Filtruji: 127177_110801-behind_of_fruit-processing_plant.wav.mp3 (220.00s)
# 🚫 Filtruji: 650430_Pistol_Reload.wav.mp3 (3.06s)
# 🚫 Filtruji: 255891_CityHum_at_lake_MS_LONG_141125_0469.flac.mp3 (2250.82s)
# 🚫 Filtruji: 514051_blaster_shot_4(Sytrus,rsmpl,2lrs,multiprcsng)series.wav.mp3 (6.03s)
# 🚫 Filtruji: 326677_Loading_gun.wav.mp3 (4.48s)
# 🚫 Filtruji: 516756_X-Shot_Chaos_Meteor_Reload_&_Shot.mp3 (14.00s)
# 🚫 Filtruji: 327128_Breaking_Ice_in_Plastic_Ice_Tray_OWI.wav.mp3 (11.00s)
# 🚫 Filtruji: 327504_Opening_bathroom_window_OWI.wav.mp3 (8.64s)
# 🚫 Filtruji: 377788_gun_9mm_25m_180_off_axis_debris_m10.wav.mp3 (31.57s)
# 🚫 Filtruji: 491299_borcegos_sobre_piso_de_madera.WAV.mp3 (27.30s)
# 🚫 Filtruji: 435396_Close_range_shots_with_wind1.wav.mp3 (5.32s)
# 🚫 Filtruji: 338321_End_of_WWII_on_Elba_-_Soviets_Celebrating.wav.mp3 (24.47s)
# 🚫 Filtruji: 148827_.22_ricochet.mp3.mp3 (5.75s)
# 🚫 Filtruji: 563015_a_loud_gunshot_in_the_woods.mp3 (3.25s)
# 🚫 Filtruji: 246275_Engine_Roar_#1.wav.mp3 (10.00s)
# 🚫 Filtruji: 81045_Pistol_or_Hand_Gun_Firing_at_wood.wav.mp3 (5.65s)
# 🚫 Filtruji: 76091_22_rifle_multiple_shots.wav.mp3 (5.47s)
# 🚫 Filtruji: 726167_SNIPERS_PRAY.mp3 (9.77s)
# 🚫 Filtruji: 674378_FlareGun_SizzleLoop01.wav.mp3 (2.15s)
# 🚫 Filtruji: 655754_Basketball.mp3.mp3 (14.00s)
# 🚫 Filtruji: 108409_SHOWER_2.wav.mp3 (14.08s)
# 🚫 Filtruji: 505201_Loading8mmMauserSingley.wav.mp3 (27.56s)
# 🚫 Filtruji: 162625_Rifles_and_Cannons,_Farther_Off.mp3 (61.26s)
# 🚫 Filtruji: 182815_Silenced_Sniper_Rifle.flac.mp3 (10.16s)
# 🚫 Filtruji: 223420_StapleGun.wav.mp3 (8.45s)
# 🚫 Filtruji: 350745_gunshooting.wav.mp3 (24.10s)
# 🚫 Filtruji: 765463_Paintbrush_on_Canvas.mp3 (14.88s)
# 🚫 Filtruji: 765506_Rattling_a_Fence.mp3 (5.00s)
# 🚫 Filtruji: 457407_MACHINE_GUN_INDOOR.wav.mp3 (3.33s)
#
# ✅ Hotovo! Odstraněno 2340 špatných souborů.
